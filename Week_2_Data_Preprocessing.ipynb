# %% [markdown]
# <a href="https://colab.research.google.com/github/mxsu/Week-2_Data_Preprocessing/blob/newBranch/Week_2_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# In this notebook, we'll explore of Artificial Intelligence Workflow, putting a spotlight on the crucial step of Data Preprocessing.
#
# To make things clear, we'll showcase different types of data. This will help you recognize how various datasets look, where you can find them, and the steps to bring them into your work.
#
# We'll also explore specific libraries tailored for each type of data. This way, you'll get hands-on experience with the tools designed to handle different data formats effectively.
#
# After that, it's time to get hands-on with these datasets. We'll take a closer look at their unique features, understand whether they present classification or regression challenges, and use visualization techniques to make sense of the data's patterns. This practical approach not only hones your skills in data preprocessing but also empowers you to smoothly integrate various libraries and techniques into your AI workflow.

# %% [markdown]
# # **Artificial Intelligence Workflow**

# %% [markdown]
# ![ml-engineering.jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Three Main Steps**:
#
# 1.   Data Preprocessing
# 2.   Model Engineering
# 3.   Model Depolyment
#
# **DATA Preprocessing**
#
#
#
# *   Data Gathering/Integration
# *   Data Exploration
# *   Data Cleaning
# *   Data Transforming
#
#
# **Model Engineering**
#
# *  Model Training
# * Model Evaluation
# * Model Testing
#
#
# **Model Deployment**
#
# * Model Serving
# * Model Performance monitoring

# %% [markdown]
# # **Important Libraries**

# %% [markdown]
# **Libraries required for importing data**:
#
# * Pandas
#
#
#
# **Libraries required for visualizing data**:
#
# * Matplotlib
# * seaborn
#
#
# **Libraries required for handling specific data types:**
#
# * Numerical =>  Numpy
# * Images =>  OpenCV
# * Text =>  NLTK
# * Audio =>  Librosa

# %%
import pandas

# %% [markdown]
# You cannot import libraries before installing them!

# %% [markdown]
# ## **Installing Libraries**
#
# If you are using Google Colab, some of the libraries are preinstalled .
#
# If you are using Anaconda, almost all the libraries will be pre installed with the package.
#
# If you have downloaded individual Jupyter notebook you will need to install all the required libraries before importing them into code.
#
# Must ensure that you have pip installed in your systems

# %%
# !python3 -m pip --version
# Out:
# pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %% [markdown]
# Install the library in Python using the pip command in the command prompt (cmd)
#
# You can also install libraries directly from the jupyter notebook by placing "!" before any command.
#
#
# ```
# !pip install package_name
# ```
#
# For the purpose of this notebook, we need to install all the above mentioned libararies, make sure to install them if they are not already installed.

# %%
#!pip install pandas
#!pip install matplotlib
#!pip install seaborn
#!pip install numpy
#!pip install opencv-python
#!pip install nltk
#!pip install librosa

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2
import nltk
import librosa

# %% [markdown]
# # **DIFFERENT TYPES OF DATA**
#
# - **Tabular Data**
#
#   - Categorical Labels
#
#   - Numerical Labels
#
# - **Textual Data**
#
# - **Images Data**
#
# - **Audio Data**

# %% [markdown]
# For Today's tutorial we will be looking into:
# - Tabular data (brief overview and pre processing)
# - Audio Data (detailed overview and pre processing)

# %% [markdown]
# ## **Tabular Data**
#  * Categorical Labels
#  * Numerical Labels

# %% [markdown]
# ### **Iris Dataset (Categorical Labels)**

# %% [markdown]
# The Iris flower data set consists of 150 samples.
#
# **Three species of Iris:**
#
# * Iris setosa
# * Iris virginica
# * Iris versicolor
#
# **Four features were measured for each sample:**
#
# * Length of the sepals (cm)
# * Width of the sepals (cm)
# * Length of the petals (cm)
# * Width of the petals (cm)
#
# **Problem Statement:**
#
# Distinguish the flowers based on these features.
#
# *Independent variables (Features)*:
# * Length of the sepals
# * Length of the petals
# * Width of the sepals
# * Width of the petals
#
# *Dependent variables (Labels)*:
# * Species of the flower

# %% [markdown]
# **Importing Required libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# **Loading Dataset**
#
#
# Download the dataset from : https://www.kaggle.com/datasets/uciml/iris
#
# Copy the path of the dataset and paste it in the command *below*

# %%
dataset_1 = pd.read_csv('/content/drive/MyDrive/IAT481/Week2/Iris.csv')

# %% [markdown]
# Preview the dataset

# %%
dataset_1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset_1.shape
# Out:
# (150, 6)

# %%
dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# When the data is simply analyzed, none of the 6 columns contain null values, which will be a great advantage. The "Species" column will be the target feature and except for the "Id" column, which can be ignored, the other columns are of type "float64".

# %%
dataset_1.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %% [markdown]
# In the describe method, apart from the parameters that are very useful for numerical features (mean, median, 1Q, 3Q etc.), parameters such as "unique, top, freq" that will be used for categorical features are indicated with "include=all".

# %%
dataset_1['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# The 3 different variables of the target feature are distributed in equal numbers.

# %%
fig,(ax1,ax2) = plt.subplots(2,2)
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.SepalLengthCm,ax=ax1[0])
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.SepalWidthCm,ax=ax1[1])
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.PetalWidthCm,ax=ax2[0])
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.PetalLengthCm,ax=ax2[1])
plt.tight_layout()
plt.show()

# %%
sns.FacetGrid(dataset_1, hue="Species") \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()

# %% [markdown]
# Explore the dataset more from : https://www.kaggle.com/datasets/uciml/iris

# %% [markdown]
# ### **House Price Prediction (Numerical Labels)**

# %% [markdown]
# Consisting of 4600 entries for homes in different US cities, this dataset includes 18 different variables that describe various property details such as size and location characteristics.
#
# **Columns**
#
# * date: Date the house was sold
# * price: Sale price of the house (Prediction target)
# * bedrooms: Number of the bedrooms
# * bathrooms: Number the bathrooms
# * sqft_living: Square footage of the home
# * sqft_lot: Square footage of the lot
# * floors: Total floors (levels) in the house
# * waterfront: House which has a view to a waterfront
# * view: Number of views
# * condition: How good the condition is overall
# * sqft_above: Square footage of the house apart from basement
# * sqft_basement: Square footage of the basement
# * yr_built: Building year of the house
# * yr_renovated: Renovation year of the house
# * street: Street where the house is located
# * city: City where the house is located
# * statezip: Zip code of the region where the house is located
# * country: Country where the house is located (USA)
#
# There are 8 categorical (half nominal and half ordinal depending on the measurement level) and 9 discrete variables.
#
# Our ordinal variables, waterfront, view and and renovation year, appear numerically, but we will evaluate them in two categories, 0 and 1, depending on whether they are in the relevant house or not. Also, the condition has 5 unique values that increase from 1 to 5 based on the state of the house. And as you might guess, street, city, statezip, and country are the nominal ones.
#
# **Types of Data**
#
# * Categorical (gender, blood type, aswers of yes/no questions, satisfaction/condition level etc.)
#
# * Numerical
#     1.   Discrete (finite numbers- # of children/customer/room,physical money, time on a clock etc.)
#     2.   Continuous (infinite numbers- measurements(weight, height), time in general etc.)
#
#
# **Levels of Measurement**
#
# * Qualitative
# a. Nominal (Can not be ordered- gender, blood type, seasons)
# b. Ordinal (Takes values with an order or rank- satisfaction, condition level)
# * Quantitative
# a. Interval (Don't have a true zero- temperature, pH, IQ test etc.)
# b. Ratios (Have a true zero- temperature only in Kelvin, amount, distance, pulse etc.)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# **Loading Dataset**
#
#
# Download the dataset from :https://www.kaggle.com/datasets/shree1992/housedata/data
# Copy the path of the dataset and paste it in the command *below*

# %%
dataset_2 = pd.read_csv("//content/drive/MyDrive/IAT481/Week2/HousePricesPredictions.csv")

# %% [markdown]
# **Exploring Dataset**

# %%
dataset_2.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 647.0+ KB

# %% [markdown]
# **Handling missing values**
#
# There is no NaN value in our data set, but it would be good to check 0's or 999's for the sake of data consistency. I don't see any irrelevant max values in the describe output but there are some zeros to check.

# %%
dataset_2[dataset_2==0].count()
# Out:
# date                0
# price              49
# bedrooms            2
# bathrooms           2
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       4567
# view             4140
# condition           0
# sqft_above          0
# sqft_basement    2745
# yr_built            0
# yr_renovated     2735
# street              0
# city                0
# statezip            0
# country             0
# dtype: int64

# %% [markdown]
# We have to deal with 49 houses that look free of cost, plus 2 houses each without a bedroom and a bathroom. Since they are few in number, we can remove these values directly from our data set.

# %%
dataset_2 = dataset_2.drop(dataset_2[(dataset_2['price']==0)].index)
dataset_2 = dataset_2.drop(dataset_2[(dataset_2['bedrooms']==0)].index)
dataset_2 = dataset_2.drop(dataset_2[(dataset_2['bathrooms']==0)].index)

# %%
dataset_2.shape
# Out:
# (4549, 18)

# %% [markdown]
# We can see now 4549 samples are left after removing samples with missing data. We can further explore the data and find outliers.

# %%
#checking the target variables for distribution
sns.histplot(dataset_2['price'])
plt.title('Price');

# %% [markdown]
# You have to remove the outliers before proceeding with the modelling. Please explore [this ](https://www.analyticsvidhya.com/blog/2021/05/feature-engineering-how-to-detect-and-remove-outliers-with-python-code/) article for outlier detection and removal.

# %% [markdown]
# For further exploration see: https://www.kaggle.com/datasets/shree1992/housedata

# %% [markdown]
# ## **Audio Data**

# %% [markdown]
# <center><h1> Introduction to Audio Data Analysis </h1></center>
#
#
# As a first step towards Speech Emotion Recognition, this notebook serves as an introduction to data cleaning and feature engineering techniques for audio data.In the next notebooks, we will delve into various Machine learning algorithms to develop models to perform classification.
#
# Data cleansing and feature engineering comprise the most crucial aspect of preparing machine and deep learning models alike and is often the difference between success and failure. We can drastically improve the performance of a model with proper attention paid to feature engineering.
# For features to be useful in classification they must encompass sufficient variance between different classes.

# %% [markdown]
# **Introduction to RAVDESS dataset**
#
# We are going to use the RAVDESS dataset (Ryerson Audio-Visual Database of Emotional Speech and Song dataset), created by Steven Livingstone and Frank Russo of Ryerson University. <br>
# **Files**
# This portion of the RAVDESS contains 1440 files: 60 trials per actor x 24 actors = 1440. The RAVDESS contains 24 professional actors (12 female, 12 male), vocalizing two lexically-matched statements in a neutral North American accent. Speech emotions includes calm, happy, sad, angry, fearful, surprise, and disgust expressions. Each expression is produced at two levels of emotional intensity (normal, strong), with an additional neutral expression.
#
# **File naming convention**
#
# Each of the 1440 files has a unique filename. The filename consists of a 7-part numerical identifier (e.g., 03-01-06-01-02-01-12.wav). These identifiers define the stimulus characteristics:
#
# **Filename identifiers**
#
# * Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
#
# * Vocal channel (01 = speech, 02 = song).
#
# * Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
#
# * Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
#
# * Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
#
# * Repetition (01 = 1st repetition, 02 = 2nd repetition).
#
# * Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# Filename example: 03-01-06-01-02-01-12.wav
#
# 1. Audio-only (03)
# 2. Speech (01)
# 3. Fearful (06)
# 4. Normal intensity (01)
# 5. Statement "dogs" (02)
# 6. 1st Repetition (01)
# 7. 12th Actor (12) Female, as the actor ID number is even.
#
# [Details of the RAVDESS dataset](https://psychlabs.torontomu.ca/smartlab/resources/speech-song-database-ravdess/) <br>
#
#
# The above link has some problems with the dataset,so i cleaned it a bit and you can access it and download it from [this link](https://drive.google.com/drive/folders/1OxhaA7DuOc7UYJZIajFlgshvdWDTLBqy?usp=sharing)
#
# We're going to use the audio-only speech portion of the RAVDESS dataset, ~200MB.
# Audio is sourced from 24 actors (12 male, 12 female) repeating two sentences with
# a variety of emotions and intensity. We get 1440 speech files (24 actors * 60 recordings per actor). Each audio sample has been rated  by a human 10 times for emotional quality.
#
# ### Machine Learning Process Overview
# 1. Feature Engineering: Choose and define the properties which our model will use to evaluate the audio files. <br>
# 2. Feature Extraction: Compute the features for each audio file and build a feature matrix representing all audio files. <br>
# 3. Model exploration: Test candidate models that make sense for the properies of the dataset
# 4. Training the MLP Classifier model: Choose and optimize the properties of our model on validation data - hyperparameters and architechture.  <br>
# 5. Evaluate our model's performance: Evaluate our model's accuracy on validation data and score it against test data which it has never seen in training.<br>
# 6. Explore options for improving our model: Is our dataset the right size? Is our model too complex or too simple? <br>

# %% [markdown]
# *In this notebook, we are going to focus on first two steps of the process.*
# 1. *Feature Engineering*
# 2. *Feature Extraction*

# %% [markdown]
# ### Feature Engineering
# Before building any sort of predictive models, we not only need data - but we need a usable representation. Enter feature engineering.
#
# An audio file can be represented as a time series with the dependent axis being
# the amplitude of the audio waveform. The waveform of the sound file is all the information we have with which to create features to train our model. However, the shape of a waveform does not carry enough discriminating information, so we need to transform the waveform into a more useable form. <br>
# Sometimes our input dataset _does_ have enough information to train a model to give accurate results - but even then input data should be scrutinized and transformed - this allows us to pick the best model for our features, which is usually much better and different than a model that works on our raw input data.  Proper feature engineering carries advantages not limited to
#
#  - **More accurate, generalizable models**
#  - **Insight into model's decision-making behaviour**
#  - **Flexibility in choice of models**
#  - **Faster training**
#
# **Before feature engineering, we always cleanse our data** - which may consist of removing outliers (carefully), removing irrelevant input data according to business logic, or removing noise. For audio, data cleaning may consistent of making audio samples equal in length and padded with silence at either end. The RAVDESS dataset has done that for us, but this is a rare case.
#
# That being said, let's see what we're starting with by comparing the waveforms of "Happy" and "Angry" of Actor 1:

# %%
# Get the critical imports out of the way
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import librosa.display
import soundfile
import os
# matplotlib complains about the behaviour of librosa.display, so we'll ignore those warnings:
import warnings; warnings.filterwarnings('ignore')
from IPython.core.display import HTML
# Center matplotlib figures...
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
################# Load Happy and Angry example of Actor 1 #####################################
with soundfile.SoundFile('/content/drive/MyDrive/IAT481/Week2/Audio_Speech_Actors_01-24/Actor_01/03-01-03-01-01-01-01.wav') as audio:
    waveform = audio.read(dtype="float32")
    sample_rate = audio.samplerate
    plt.figure(figsize=(15,4))
    plt.subplot(1, 2, 1)
    librosa.display.waveshow(waveform, sr=sample_rate)
    plt.title('Happy')

with soundfile.SoundFile('/content/drive/MyDrive/IAT481/Week2/Audio_Speech_Actors_01-24/Actor_01/03-01-05-01-01-01-01.wav') as audio:
    waveform = audio.read(dtype="float32")
    sample_rate = audio.samplerate
    plt.subplot(1, 2, 2)
    librosa.display.waveshow(waveform, sr=sample_rate)
    plt.title('Angry')

# %%
################# Load Happy and Angry example of Actor 1 #####################################
# 1 Modality (01 = full-AV, 02 = video-only, 03 = audio-only).

# 2 Vocal channel (01 = speech, 02 = song).

# 3 Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).

# 4 Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.

# 5 Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").

# 6 Repetition (01 = 1st repetition, 02 = 2nd repetition).

# 7 Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).


with soundfile.SoundFile('/content/drive/MyDrive/IAT481/Week2/wav/03a01Wa.wav') as audio:
    waveform = audio.read(dtype="float32")
    sample_rate = audio.samplerate
    plt.figure(figsize=(15,4))
    plt.subplot(1, 2, 1)
    librosa.display.waveshow(waveform, sr=sample_rate)
    plt.title('Happy German male')

with soundfile.SoundFile('/content/drive/MyDrive/IAT481/Week2/wav/13a01Fd.wav') as audio:
    waveform = audio.read(dtype="float32")
    sample_rate = audio.samplerate
    plt.subplot(1, 2, 2)
    librosa.display.waveshow(waveform, sr=sample_rate)
    plt.title('Happy German female')

# %% [markdown]
# Alright, there's a visible difference - but not enough to classify by emotion. Take my word for it. Try it if you like. However, raw waveforms can be used for certain other audio classification tasks with the right network.

# %% [markdown]
# So, where do we get features suitable for emotion classification?
# ### Short-Time Fourier Transform
# The lowest-hanging fruit in time series signal processing is, of course, the Fourier Transform.
# Specifically, we'll use the Short-Time Fourier Transform (STFT) which will cut our audio waveform into short, overlapping equal length segments and
# take the Fourier transform of each segment individually to produce multiple power spectrograms, identifying resonant frequencies present in our audio file. The major advantage of STFT is better resolution of _changes_ in the audio signal w.r.t. time. <br>
#
# If you want to explore Fourier transform please look into [this article.](https://medium.com/@ongzhixuan/exploring-the-short-time-fourier-transform-analyzing-time-varying-audio-signals-98157d1b9a12)

# %% [markdown]
# Let's start visualizing our features to get a better handle on them.
# Load a sample audio file from our dataset - each audio file is 3 seconds in length.

# %%
with soundfile.SoundFile('/content/drive/MyDrive/IAT481/Week2/wav/03a01Wa.wav') as audio:
    happy_waveform = audio.read(dtype="float32")
    sample_rate = audio.samplerate

with soundfile.SoundFile('/content/drive/MyDrive/IAT481/Week2/wav/13a01Fd.wav') as audio:
    angry_waveform = audio.read(dtype="float32")
    # same sample rate

# %% [markdown]
# ##### Visualize the combination of power spectrograms output by STFT w.r.t time:

# %%
stft_spectrum_matrix = librosa.stft(happy_waveform)
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.amplitude_to_db(np.abs(stft_spectrum_matrix), ref=np.max),y_axis='log', x_axis='time')
plt.title('Happy German Male STFT Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

stft_spectrum_matrix = librosa.stft(angry_waveform)
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.amplitude_to_db(np.abs(stft_spectrum_matrix), ref=np.max),y_axis='log', x_axis='time')
plt.title('Happy German Female STFT Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()

# %% [markdown]
# We're getting somewhere, but we're going to have to go further. We operate under the assumption that features whose interclass differences we can visualize will be good candidates on which to train a neural network. Looks like further transformations on the STFT will yield good features. Since we have a 3 second audio file, STFT spectrograms for these audio samples combine to show the change in frequencies across a 3 second window.

# %% [markdown]
# ###Mel-Frequency Cepstral Coefficients
# We're going to build on the STFT by using the Mel Frequency Cepstral Coefficients (MFCCs) as a feature.
# In brief, MFCC is a mathematical method which transforms the power spectrum of an audio signal to a small number of coefficients representing power of the audio signal in a frequency region (a region of pitch) taken w.r.t. time.
# <br><br>
# In other words, MFC coefficients give us an idea of the changing pitch of an audio signal.
#
# To understand our major feature a little better, we should at least have a vague idea of the math behind it.
# MFCC at its core uses STFT to produce audio power spectrums. We then apply triangular, overlapping window functions to the power spectrograms and take the sum of energy in each window which is essentialy a frequency bin. To determine the number and position of window functions, and width of each frequency bin, we map the frequencies of our audio's power spectrograms to the [Mel scale](https://en.wikipedia.org/wiki/Mel_scale), a nonlinear pitch scale representing the perceived pitch in 'mels' of an audio signal w.r.t. its frequency. The motivation for the mel scale is to account for the way human hearing perceives pitch based on frequency ratios rather than absolute differences in frequencies. The window functions/frequency bins we applied in this step are called mel filterbanks.
#
# Now we can take the log of the sum of power in each mel frequency filterbank. Taking the log power of an audio spectrogram produces a cepstrum - more on this a little later.
#
# ###### The Discrete Cosine Transform
# Finally, we apply the discrete cosine transform [(DCT)](https://en.wikipedia.org/wiki/Discrete_cosine_transform) to the log of power in each filterbank. The DCT carries distinguished advantages: Because triangular window functions overlap, the mel filterbank energies are correlated with each other; DCT decorellates the signals; DCT produces coefficients such that usually only the top few coefficients are necessary to represent a signal with fair accuracy, i.e. a compressed representation. **In this way, DCT is quite similar to PCA** - one key difference being that DCT has an absolute definition while PCA is only defined w.r.t. a dataset. For this reason (and a couple others) DCT sees a _huge_ range of applicability: image and audio data compression (read: internet, wireless tech, medicine) and cryptography are most notable. Our MFC coefficients are then the amplitudes of each DCT-transformed log filterbank power, taken w.r.t. time.
#
# Another way to think about MFCC is as a deconvolution method to identify periodic, or resonant structures within an audio signal's frequency space. We can visualize our MFC coefficients by plotting the coefficients provided by each mel filterbank against time.
#
# I've found for this task that 40 filterbanks producing 40 coefficients provide the best accuracy and quick computation.
#
# You can further explore the Mel-Frequency Cepstral Coefficients from
#  [this article.](https://medium.com/@derutycsl/intuitive-understanding-of-mfccs-836d36a1f779)

# %% [markdown]
# ###### Visualize our sample's MFC coefficients w.r.t time:

# %%
from matplotlib.colors import Normalize
mfc_coefficients = librosa.feature.mfcc(y=happy_waveform, sr=sample_rate, n_mfcc=40)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfc_coefficients, x_axis='time',norm=Normalize(vmin=-30,vmax=30))
plt.colorbar()
plt.yticks(())
plt.ylabel('MFC Coefficient')
plt.title('Happy German male MFC Coefficients')
plt.tight_layout()

mfc_coefficients = librosa.feature.mfcc(y=angry_waveform, sr=sample_rate, n_mfcc=40)
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfc_coefficients, x_axis='time',norm=Normalize(vmin=-30,vmax=30))
plt.colorbar()
plt.yticks(())
plt.ylabel('MFC Coefficient')
plt.title('Happy German Female MFC Coefficients')
plt.tight_layout()

# %% [markdown]
# **Positive MFCCs correspond to low-frequency regions of the cepstrum, and negative MFFCs to high-frequency.**
#
# **We see the Angry voice has a much greater proportion of positive MFFCs, corresponding to a lower voice pitch compared to the Happy voice. Makes sense - a happy voice carries a lighter tone and a higher pitch.**

# %% [markdown]
# ##### Quick MFCC Derivation
# 1. Take the square of magnitudes in spectrograms produced by STFT to produce audio power spectrograms for short overlapping frames of the audio signal, <br>
# 2. Apply a mel-scale-based transformation, mel filterbanks (triangular window functions) to each STFT power spectrogram and sum the power in each filterbank <br>
# 3. Take the log of each filterbank power <br>
# 4. Take the discrete cosine transform of each log power in each STFT frame, giving us the MFC coefficients - our measure of power at various mel frequencies, corresponding to audible pitch. <br>
#
# Wikipedia has a pretty straight-forward explanation of [MFCCs](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum).

# %% [markdown]
# ### Mel Spectrograms and Mel-Frequency Cepstrums
# In deriving our MFCCs, we have also produced an additional feature we can make use of.
# When we mapped the frequencies of a power spectrogram to the mel scale, we produced a Mel Frequency Spectrogram -
# a simple analog of the power spectrogram with the frequency scale in mels.
# We're going to use the Mel Specotrgrogram as a feature of its own.

# %% [markdown]
# ##### Visualize our sample's Mel spectrogram w.r.t time:

# %%
melspectrogram = librosa.feature.melspectrogram(y=happy_waveform, sr=sample_rate, n_mels=128, fmax=8000)
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(S=melspectrogram, ref=np.mean),y_axis='mel',fmax=8000, x_axis='time', norm=Normalize(vmin=-20,vmax=20))
plt.colorbar(format='%+2.0f dB',label='Amplitude')
plt.ylabel('Mels')
plt.title('Happy German Male spectrogram')
plt.tight_layout()

melspectrogram = librosa.feature.melspectrogram(y=angry_waveform, sr=sample_rate, n_mels=128, fmax=8000)
plt.figure(figsize=(10, 4))
librosa.display.specshow(librosa.power_to_db(S=melspectrogram, ref=np.mean),y_axis='mel',fmax=8000, x_axis='time', norm=Normalize(vmin=-20,vmax=20))
plt.colorbar(format='%+2.0f dB',label='Amplitude')
plt.ylabel('Mels')
plt.title('Happy German female Mel spectrogram')
plt.tight_layout()

# %% [markdown]
# **The Angry voice produces sharper transitions between mel frequency peaks compared to the Happy voice, which has smoother pitch transitions. That makes intuitive sense - an Angry voice has sharp transitions while a happy voice is more steady and pleasing to the ears. Mel spectrograms will make another good feature.**
#
# What about the cepstrum? When we took the log of the spectral amplitudes in a Mel-scaled power spectrogram, we could have plotted that result as a time series and produced what is known as a 'mel-frequency cepstrum', now in the 'quefrency' domain, so confusingly named because we have applied a transformation to an audio signal in its frequency domain, but have plotted it as a time series - not quite in the frequency domain, not quite in the time domain. In the cepstrum, we observe a peak wherever there is a periodic element in the original audio signal. We've actually already used the the mel-frequency cepstrum (MFC) as a feature, since that is precisely the source of our MFC coefficients. Again, Wikipedia has a fairly palatable explanation of the [cepstrum](https://en.wikipedia.org/wiki/Cepstrum).
#
# Below is an excellent visualization of the transformations between waveform, spectrogram, mel spectrogram, and MFCCs plotted as time series.
# The vertical frame in each graph represents a single STFT frame.<br>

# %% [markdown]
# ![mfcc.gif](data:image/gif;base64,...)

# %% [markdown]
# ### The Chromagram
# To extract an additional feature, we're going to build a chromagram on each power spectrogram computed by STFT. A chromagram is a representation of an audio signal w.r.t. time, mapping audio signal to a pitch class.
# Most often, we map to the 12 standard pitch classes (i.e. the musical scale CDEFGAB + 5 semitones gives us 12 pitch classes).
# Again, wikipedia has a short and sweet [explanation](https://en.wikipedia.org/wiki/Chroma_feature).

# %% [markdown]
# ##### Visualize the chromagram for our sample audio:

# %%
chromagram = librosa.feature.chroma_stft(y=happy_waveform, sr=sample_rate)
plt.figure(figsize=(10, 4))
librosa.display.specshow(chromagram, y_axis='chroma', x_axis='time')
plt.colorbar(label='Relative Intensity')
plt.title('Happy German Male Chromagram')
plt.tight_layout()

chromagram = librosa.feature.chroma_stft(y=angry_waveform, sr=sample_rate)
plt.figure(figsize=(10, 4))
librosa.display.specshow(chromagram, y_axis='chroma', x_axis='time')
plt.colorbar(label='Relative Intensity')
plt.title('Happy German female Chromagram')
plt.tight_layout()

# %%
print(chromagram.shape)
# Out:
# (12, 59)

# %% [markdown]
# **The pitch distribution of the Angry voice has a much lower dispersion compared to the Happy voice, whose pitch has a higher dispersion at any point in time. This makes intuitive sense considering the tone of an angry voice is more intense and "snappy" compared to a happy voice, which is smoother to the ears - here's a good explanation as to why. This should make a good feature.**

# %% [markdown]
# ### Feature Extraction
# We're going to take full advantage of librosa, a Python library enabling audio analysis and feature extraction.
# Librosa abstracts away all the math and most of the details of mel spectrorgams, chromagrams, and MFCC.
# Although closely related, we're going to take the Mel Spectrogram, MFCC, and chromagrams of each audio file as separate features to try
# and have bit more discriminatory power between samples. <br>
#
# Let's build our feature extraction functions to get a chromagram, a mel spectorgram, and MFC coefficients for each of our audio files. Because the chromagram, mel spectrogram and MFCCs are calculated on audio frames produced by STFT, we're going to get a matrix back from each function, so we'll take the mean of those matrices to produce a single feature array for each feature and each audio sample, i.e. 3 feature arrays per audio sample.
#
# **Chromagram**: Will produce 12 features; One for each of 12 pitch classes
#
# **Mel Spectrogram**: Will produce 128 features; We've defined the number of mel frequency bands at n_mels=128
#
# **MFCC**: Will produce 40 MFCCs; I've set the number of coefficients to return at n_mfcc=40 which I found to work well

# %%
import librosa

def feature_chromagram(waveform, sample_rate):
    # STFT computed here explicitly; mel spectrogram and MFCC functions do this under the hood
    stft_spectrogram=np.abs(librosa.stft(waveform))
    #print(stft_spectrogram.shape)
    # Produce the chromagram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    chromagram=np.mean(librosa.feature.chroma_stft(S=stft_spectrogram, sr=sample_rate).T,axis=0)
    #print(chromagram.shape)
    return chromagram

def feature_melspectrogram(waveform, sample_rate):
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram=np.mean(librosa.feature.melspectrogram(y=waveform, sr=sample_rate, n_mels=128, fmax=8000).T,axis=0)
    return melspectrogram

def feature_mfcc(waveform, sample_rate):
    # Compute the MFCCs for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # 40 filterbanks = 40 coefficients
    mfc_coefficients=np.mean(librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=40).T, axis=0)
    return mfc_coefficients

# %% [markdown]
# We're going to wrap our feature extraction functions so we only have to load each audio file once. After extracting our 3 audio features as NumPy arrays representing a time series, we're going to
# stack them horizontally to create a single feature array.

# %%
def get_features(file):
    # load an individual soundfile
     with soundfile.SoundFile(file) as audio:
        waveform = audio.read(dtype="float32")
        sample_rate = audio.samplerate
        # compute features of soundfile
        chromagram = feature_chromagram(waveform, sample_rate)
        melspectrogram = feature_melspectrogram(waveform, sample_rate)
        mfc_coefficients = feature_mfcc(waveform, sample_rate)
        feature_matrix=np.array([])

        # use np.hstack to stack our feature arrays horizontally to create a feature matrix
        feature_matrix = np.hstack((chromagram, melspectrogram, mfc_coefficients))

        return feature_matrix

# %% [markdown]
# ### Load the Dataset and Compute Features
# We have to understand the labelling of the RAVDESS dataset to find the ground truth emotion for each sample.
# Each file is labelled with 7 numbers delimited by a "-".
# Most of the numbers describe metadata about the audio samples such as their format (video and/or audio),
# whether the audio is a song or statement, which of two statements is being read and by which actor.
#
# The third and fourth numbers pertain to the emotional quality of each sample. The third number is in the range of 1-8 with each number representing an emotion.
# The fourth number is either 1 or 2, representing normal (1) or strong (2) emotional intensity.
#
# We're going to define a dictionary based on the third number (emotion) and assign an emotion to each number as specified by the RAVDESS dataset:

# %%
#Emotions in the RAVDESS dataset
emotionsRAVDESS ={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}
gendersRAVDESS={
    '01':'male',
    '02':'female',
    '03':'male',
    '04':'female',
    '05':'male',
    '06':'female',
    '07':'male',
    '08':'female',
    '09':'male',
    '10':'female',
    '11':'male',
    '12':'female',
    '13':'male',
    '14':'female',
    '15':'male',
    '16':'female',
    '17':'male',
    '18':'female',
    '19':'male',
    '20':'female',
    '21':'male',
    '22':'female',
    '23':'male',
    '24':'female',
}

#EMOTIONS IN EMODB

emotionsDB = {
    #'A':'angry',
    'W':'angry',
    #'B':'boredom',
    'L':'boredom',
    #'D':'disgut',
    'E':'disgust',
    #'F':'fearful',
    'A':'fearful',
    #'H':'happy',
    'F':'happy',
    #'S':'sadness',
    'T':'sad',
    'N':'neutral'
}

gendersDB = {
    '03':'male',
    '08':'female',
    '09':'female',
    '10':'male',
    '11':'male',
    '12':'male',
    '13':'female',
    '14':'female',
    '15':'male',
    '16':'female',
}

# %% [markdown]
# Finally, let's load our entire dataset and compute the features of each audio file:

# %%
import os, glob
import numpy as np


def load_dataRAV():
    X,y,z=[],[],[]
    count = 0
    for file in glob.glob("/content/drive/MyDrive/IAT481/Week2/Audio_Speech_Actors_01-24/Actor_*/*.wav"):
        file_name=os.path.basename(file)
        print(file_name)
        #print(file_name.split("-")[2])
        #print("emotion " + file_name[18:20])
        #print("gender: " + file_name[6:8])
        emotionRAV=emotionsRAVDESS[(file_name[6:8])]
        print(emotionRAV)
        featuresRAV = get_features(file)
        # print(features)
        genderRAV=gendersRAVDESS[(file_name[18:20])]
        print(genderRAV)
        X.append(featuresRAV)
        y.append(emotionRAV)
        z.append(genderRAV)
        count += 1
        # '\r' + end='' results in printing over same line
        print('\r' + f' Processed {count}/{1435} audio samples',end=' ')
      # Return arrays to plug into sklearn's cross-validation algorithms
    return np.array(X), np.array(y), np.array(z)

# %%
import os, glob
import numpy as np


def load_dataEmo():
    X,y,z=[],[],[]
    count = 0
    for file in glob.glob("/content/drive/MyDrive/IAT481/Week2/wav/*.wav"):
        file_name=os.path.basename(file)
        print(file_name)
        features = get_features(file)
        emotionEmo=emotionsDB[file_name[5]]
        genderEmo=gendersDB[(file_name[0:2])]
        # print(features)
        print(genderEmo)
        print(emotionEmo)
        X.append(features)
        y.append(emotionEmo)
        z.append(genderEmo)
        count += 1
        # '\r' + end='' results in printing over same line
        print('\r' + f' Processed {count}/{1435} audio samples',end=' ')
      # Return arrays to plug into sklearn's cross-validation algorithms
    return np.array(X), np.array(y), np.array(z)

# %% [markdown]
# Compute the feature matrix and read the emotion labels for the entire dataset.
# Note that our regressor (independent/explanatory variable), usually denoted X, is named 'features', and our regressand (dependent variable), usually denoted y, is named 'emotions'.

# %%
featuresRAV, emotionsRAV, gendersRAV = load_dataRAV()
# Out:
# 03-01-01-01-01-01-05.wav
# neutral
# male
#  Processed 1/1435 audio samples 03-01-02-02-02-02-05.wav
# calm
# male
#  Processed 2/1435 audio samples 03-01-02-02-02-01-05.wav
# calm
# male
#  Processed 3/1435 audio samples 03-01-01-01-02-02-05.wav
# neutral
# male
#  Processed 4/1435 audio samples 03-01-02-02-01-02-05.wav
# calm
# male
#  Processed 5/1435 audio samples 03-01-01-01-02-01-05.wav
# neutral
# male
#  Processed 6/1435 audio samples 03-01-02-01-02-01-05.wav
# calm
# male
#  Processed 7/1435 audio samples 03-01-01-01-01-02-05.wav
# neutral
# male
#  Processed 8/1435 audio samples 03-01-02-01-01-01-05.wav
# calm
# male
#  Processed 9/1435 audio samples 03-01-02-02-01-01-05.wav
# calm
# male
#  Processed 10/1435 audio samples 03-01-02-01-01-02-05.wav
# calm
# male
#  Processed 11/1435 audio samples 03-01-05-01-02-02-05.wav
# angry
# male
#  Processed 12/1435 audio samples 03-01-04-02-01-02-05.wav
# sad
# male
#  Processed 13/1435 audio samples 03-01-03-01-01-01-05.wav
# happy
# male
#  Processed 14/1435 audio samples 03-01-04-02-01-01-05.wav
# sad
# male
#  Processed 15/1435 audio samples 03-01-04-01-01-02-05.wav
# sad
# male
# calm
# male
#  Processed 131/1435 audio samples 03-01-03-01-02-01-03.wav
# happy
# male
#  Processed 132/1435 audio samples 03-01-03-02-01-02-03.wav
# happy
# male
#  Processed 133/1435 audio samples 03-01-02-02-01-01-03.wav
# calm
# male
#  Processed 134/1435 audio samples 03-01-02-02-02-02-03.wav
# calm
# male
#  Processed 135/1435 audio samples 03-01-03-02-02-02-03.wav
# happy
# male
#  Processed 136/1435 audio samples 03-01-05-01-01-02-03.wav
# angry
# male
#  Processed 137/1435 audio samples 03-01-03-01-01-02-03.wav
# happy
# male
#  Processed 138/1435 audio samples 03-01-04-01-02-01-03.wav
# sad
# male
#  Processed 139/1435 audio samples 03-01-02-02-01-02-03.wav
# calm
# male
#  Processed 140/1435 audio samples 03-01-04-01-01-02-03.wav
# sad
# male
#  Processed 141/1435 audio samples 03-01-04-01-01-01-03.wav
# sad
# male
#  Processed 142/1435 audio samples 03-01-04-02-01-01-03.wav
# sad
# male
#  Processed 143/1435 audio samples 03-01-03-02-02-01-03.wav
# happy
# male
#  Processed 144/1435 audio samples 03-01-03-01-02-02-03.wav
# happy
# male
#  Processed 145/1435 audio samples 03-01-03-01-01-01-03.wav
# happy
# male
#  Processed 146/1435 audio samples 03-01-05-01-02-02-03.wav
# angry
# male
#  Processed 147/1435 audio samples 03-01-04-02-02-01-03.wav
# sad
# male
#  Processed 148/1435 audio samples 03-01-04-02-02-02-03.wav
# sad
# male
#  Processed 149/1435 audio samples 03-01-05-01-01-01-03.wav
# angry
# male
#  Processed 150/1435 audio samples 03-01-03-02-01-01-03.wav
# happy
# male
#  Processed 151/1435 audio samples 03-01-06-01-01-02-03.wav
# fearful
# male
#  Processed 152/1435 audio samples 03-01-08-01-02-02-03.wav
# surprised
# male
#  Processed 153/1435 audio samples 03-01-08-02-01-01-03.wav
# surprised
# male
#  Processed 154/1435 audio samples 03-01-06-01-02-01-03.wav
# fearful
# male
#  Processed 155/1435 audio samples 03-01-07-02-02-01-03.wav
# disgust
# male
#  Processed 156/1435 audio samples 03-01-07-01-01-02-03.wav
# disgust
# male
#  Processed 157/1435 audio samples 03-01-08-01-01-01-03.wav
# surprised
# male
#  Processed 158/1435 audio samples 03-01-05-02-01-01-03.wav
# angry
# male
#  Processed 159/1435 audio samples 03-01-06-01-01-01-03.wav
# fearful
# male
#  Processed 160/1435 audio samples 03-01-08-01-02-01-03.wav
# surprised
# male
#  Processed 161/1435 audio samples 03-01-07-01-01-01-03.wav
# disgust
# male
#  Processed 162/1435 audio samples 03-01-06-02-01-01-03.wav
# fearful
# male
#  Processed 163/1435 audio samples 03-01-07-02-01-01-03.wav
# disgust
# male
#  Processed 164/1435 audio samples 03-01-07-02-02-02-03.wav
# disgust
# male
#  Processed 165/1435 audio samples 03-01-05-02-02-01-03.wav
# angry
# male
#  Processed 166/1435 audio samples 03-01-07-01-02-02-03.wav
# disgust
# male
#  Processed 167/1435 audio samples 03-01-05-02-02-02-03.wav
# angry
# male
#  Processed 168/1435 audio samples 03-01-08-01-01-02-03.wav
# surprised
# male
#  Processed 169/1435 audio samples 03-01-07-01-02-01-03.wav
# disgust
# male
#  Processed 170/1435 audio samples 03-01-06-01-02-02-03.wav
# fearful
# male
#  Processed 171/1435 audio samples 03-01-07-02-01-02-03.wav
# disgust
# male
#  Processed 172/1435 audio samples 03-01-06-02-01-02-03.wav
# fearful
# male
#  Processed 173/1435 audio samples 03-01-06-02-02-01-03.wav
# fearful
# male
#  Processed 174/1435 audio samples 03-01-06-02-02-02-03.wav
# fearful
# male
#  Processed 175/1435 audio samples 03-01-05-02-01-02-03.wav
# angry
# male
#  Processed 176/1435 audio samples 03-01-08-02-02-01-03.wav
# surprised
# male
#  Processed 177/1435 audio samples 03-01-08-02-02-02-03.wav
# surprised
# male
#  Processed 178/1435 audio samples 03-01-08-02-01-02-03.wav
# surprised
# male
#  Processed 179/1435 audio samples 03-01-02-01-02-02-01.wav
# calm
# male
#  Processed 180/1435 audio samples 03-01-02-01-01-01-01.wav
# calm
# male
#  Processed 181/1435 audio samples 03-01-01-01-02-01-01.wav
# neutral
# male
#  Processed 182/1435 audio samples 03-01-02-02-01-01-01.wav
# calm
# male
#  Processed 183/1435 audio samples 03-01-02-01-02-01-01.wav
# calm
# male
#  Processed 184/1435 audio samples 03-01-01-01-01-01-01.wav
# neutral
# male
#  Processed 185/1435 audio samples 03-01-01-01-02-02-01.wav
# neutral
# male
#  Processed 186/1435 audio samples 03-01-01-01-01-02-01.wav
# neutral
# male
#  Processed 187/1435 audio samples 03-01-04-02-01-01-01.wav
# sad
# male
#  Processed 188/1435 audio samples 03-01-05-01-02-02-01.wav
# angry
# male
#  Processed 189/1435 audio samples 03-01-05-01-01-02-01.wav
# angry
# male
#  Processed 190/1435 audio samples 03-01-05-01-02-01-01.wav
# angry
# male
#  Processed 191/1435 audio samples 03-01-03-02-01-01-01.wav
# happy
# male
#  Processed 192/1435 audio samples 03-01-04-01-01-02-01.wav
# sad
# male
#  Processed 193/1435 audio samples 03-01-03-01-02-02-01.wav
# happy
# male
#  Processed 194/1435 audio samples 03-01-04-01-01-01-01.wav
# sad
# male
#  Processed 195/1435 audio samples 03-01-05-02-01-02-01.wav
# angry
# male
#  Processed 196/1435 audio samples 03-01-04-02-01-02-01.wav
# sad
# male
#  Processed 197/1435 audio samples 03-01-03-02-02-02-01.wav
# happy
# male
#  Processed 198/1435 audio samples 03-01-03-01-02-01-01.wav
# happy
# male
#  Processed 199/1435 audio samples 03-01-02-02-02-02-01.wav
# calm
# male
#  Processed 200/1435 audio samples 03-01-04-02-02-02-01.wav
# sad
# male
#  Processed 201/1435 audio samples 03-01-02-02-01-02-01.wav
# calm
# male
#  Processed 202/1435 audio samples 03-01-03-01-01-01-01.wav
# happy
# male
#  Processed 203/1435 audio samples 03-01-04-02-02-01-01.wav
# sad
# male
#  Processed 204/1435 audio samples 03-01-05-02-01-01-01.wav
# angry
# male
#  Processed 205/1435 audio samples 03-01-02-02-02-01-01.wav
# calm
# male
#  Processed 206/1435 audio samples 03-01-05-01-01-01-01.wav
# angry
# male
#  Processed 207/1435 audio samples 03-01-04-01-02-02-01.wav
# sad
# male
#  Processed 208/1435 audio samples 03-01-03-01-01-02-01.wav
# happy
# male
#  Processed 209/1435 audio samples 03-01-03-02-01-02-01.wav
# happy
# male
#  Processed 210/1435 audio samples 03-01-03-02-02-01-01.wav
# happy
# male
#  Processed 211/1435 audio samples 03-01-04-01-02-01-01.wav
# sad
# male
#  Processed 212/1435 audio samples 03-01-08-01-01-01-01.wav
# surprised
# male
#  Processed 213/1435 audio samples 03-01-06-01-02-02-01.wav
# fearful
# male
#  Processed 214/1435 audio samples 03-01-07-01-01-01-01.wav
# disgust
# male
#  Processed 215/1435 audio samples 03-01-07-01-02-01-01.wav
# disgust
# male
#  Processed 216/1435 audio samples 03-01-06-02-01-01-01.wav
# fearful
# male
#  Processed 217/1435 audio samples 03-01-06-01-02-01-01.wav
# fearful
# male
#  Processed 218/1435 audio samples 03-01-06-01-01-02-01.wav
# fearful
# male
#  Processed 219/1435 audio samples 03-01-08-01-01-02-01.wav
# surprised
# male
#  Processed 220/1435 audio samples 03-01-07-02-01-01-01.wav
# disgust
# male
#  Processed 221/1435 audio samples 03-01-07-02-02-01-01.wav
# disgust
# male
#  Processed 222/1435 audio samples 03-01-07-02-01-02-01.wav
# disgust
# male
#  Processed 223/1435 audio samples 03-01-08-02-01-01-01.wav
# surprised
# male
#  Processed 224/1435 audio samples 03-01-08-02-01-02-01.wav
# surprised
# male
#  Processed 225/1435 audio samples 03-01-06-02-01-02-01.wav
# fearful
# male
#  Processed 226/1435 audio samples 03-01-07-02-02-02-01.wav
# disgust
# male
#  Processed 227/1435 audio samples 03-01-05-02-02-02-01.wav
# angry
# male
#  Processed 228/1435 audio samples 03-01-07-01-01-02-01.wav
# disgust
# male
#  Processed 229/1435 audio samples 03-01-06-02-02-01-01.wav
# fearful
# male
#  Processed 230/1435 audio samples 03-01-06-01-01-01-01.wav
# fearful
# male
#  Processed 231/1435 audio samples 03-01-06-02-02-02-01.wav
# fearful
# male
#  Processed 232/1435 audio samples 03-01-05-02-02-01-01.wav
# angry
# male
#  Processed 233/1435 audio samples 03-01-08-01-02-01-01.wav
# surprised
# male
#  Processed 234/1435 audio samples 03-01-07-01-02-02-01.wav
# disgust
# male
#  Processed 235/1435 audio samples 03-01-08-02-02-01-01.wav
# surprised
# male
#  Processed 236/1435 audio samples 03-01-08-02-02-02-01.wav
# surprised
# male
#  Processed 237/1435 audio samples 03-01-02-01-01-01-04.wav
# calm
# female
#  Processed 238/1435 audio samples 03-01-02-01-02-01-04.wav
# calm
# female
#  Processed 239/1435 audio samples 03-01-02-02-01-01-04.wav
# calm
# female
#  Processed 240/1435 audio samples 03-01-03-02-02-02-04.wav
# happy
# female
#  Processed 241/1435 audio samples 03-01-03-01-02-02-04.wav
# happy
# female
#  Processed 242/1435 audio samples 03-01-03-02-02-01-04.wav
# happy
# female
#  Processed 243/1435 audio samples 03-01-04-01-01-02-04.wav
# sad
# female
#  Processed 244/1435 audio samples 03-01-02-01-01-02-04.wav
# calm
# female
#  Processed 245/1435 audio samples 03-01-03-02-01-01-04.wav
# male
# angry
#  Processed 2/1435 audio samples 03a02Nc.wav
# male
# neutral
#  Processed 3/1435 audio samples 03a02Fc.wav
# male
# happy
#  Processed 4/1435 audio samples 03a01Fa.wav
# male
# happy
#  Processed 5/1435 audio samples 03a01Nc.wav
# male
# neutral
#  Processed 6/1435 audio samples 03a01Wa.wav
# male
# angry
#  Processed 7/1435 audio samples 03a07Fa.wav
# male
# happy
#  Processed 8/1435 audio samples 11a02Wc.wav
# male
# angry
#  Processed 9/1435 audio samples 08a02Ac.wav
# female
# fearful
#  Processed 10/1435 audio samples 08b02Tc.wav
# female
# sad
#  Processed 11/1435 audio samples 09b03Fd.wav
# female
# happy
#  Processed 12/1435 audio samples 09a07Eb.wav
# female
# disgust
#  Processed 13/1435 audio samples 09a04La.wav
# female
# boredom
#  Processed 14/1435 audio samples 09a07Ta.wav
# female
# sad
#  Processed 15/1435 audio samples 08a07Wc.wav
# female
# angry
#  Processed 16/1435 audio samples 03a04Nc.wav
# male
# neutral
#  Processed 17/1435 audio samples 08a07Tb.wav
# female
# sad
#  Processed 18/1435 audio samples 03a07Wc.wav
# male
# angry
#  Processed 19/1435 audio samples 08a02Wc.wav
# female
# angry
#  Processed 20/1435 audio samples 09a02Eb.wav
# female
# disgust
#  Processed 21/1435 audio samples 08b01Wa.wav
# female
# angry
#  Processed 22/1435 audio samples 11a04Nd.wav
# male
# neutral
#  Processed 23/1435 audio samples 03b10Ab.wav
# male
# fearful
#  Processed 24/1435 audio samples 10b03Tb.wav
# male
# sad
#  Processed 25/1435 audio samples 09b02Wd.wav
# female
# angry
#  Processed 26/1435 audio samples 11a02Nc.wav
# male
# neutral
#  Processed 27/1435 audio samples 08a07Ta.wav
# female
# sad
#  Processed 28/1435 audio samples 09b01Ea.wav
# female
# disgust
#  Processed 29/1435 audio samples 09a01Fa.wav
# female
# happy
#  Processed 30/1435 audio samples 09b03Nb.wav
# female
# neutral
#  Processed 31/1435 audio samples 08a07Fd.wav
# female
# happy
#  Processed 32/1435 audio samples 10a07Aa.wav
# male
# fearful
#  Processed 33/1435 audio samples 10a05Ld.wav
# male
# boredom
#  Processed 34/1435 audio samples 03a04Wc.wav
# male
# angry
#  Processed 35/1435 audio samples 08a07Na.wav
# female
# neutral
#  Processed 36/1435 audio samples 08b02La.wav
# female
# boredom
#  Processed 37/1435 audio samples 09a02Ea.wav
# female
# disgust
#  Processed 38/1435 audio samples 11a02Ec.wav
# male
# disgust
#  Processed 39/1435 audio samples 10a07Ad.wav
# male
# fearful
#  Processed 40/1435 audio samples 11a05Fb.wav
# male
# happy
#  Processed 41/1435 audio samples 08b03Tc.wav
# female
# sad
#  Processed 42/1435 audio samples 09a05Tb.wav
# female
# sad
#  Processed 43/1435 audio samples 10a04Nb.wav
# male
# neutral
#  Processed 44/1435 audio samples 08a02Fe.wav
# female
# happy
#  Processed 45/1435 audio samples 11a05Fc.wav
# male
# happy
#  Processed 46/1435 audio samples 03a07Nc.wav
# male
# neutral
#  Processed 47/1435 audio samples 11a04Wc.wav
# male
# angry
#  Processed 48/1435 audio samples 10a01Wa.wav
# male
# angry
#  Processed 49/1435 audio samples 09a07Na.wav
# female
# neutral
#  Processed 50/1435 audio samples 08b03Fe.wav
# female
# happy
#  Processed 51/1435 audio samples 03a04Fd.wav
# male
# happy
#  Processed 52/1435 audio samples 09a04Nb.wav
# female
# neutral
#  Processed 53/1435 audio samples 08a04Tb.wav
# female
# sad
#  Processed 54/1435 audio samples 11a01Wc.wav
# male
# angry
#  Processed 55/1435 audio samples 10b02Na.wav
# male
# neutral
#  Processed 56/1435 audio samples 03a05Fc.wav
# male
# happy
#  Processed 57/1435 audio samples 03b02La.wav
# male
# boredom
#  Processed 58/1435 audio samples 09b02Wc.wav
# female
# angry
#  Processed 59/1435 audio samples 09b03Ta.wav
# female
# sad
#  Processed 60/1435 audio samples 03b01Wa.wav
# male
# angry
#  Processed 61/1435 audio samples 03b09Tc.wav
# male
# sad
#  Processed 62/1435 audio samples 03a04Ad.wav
# male
# fearful
#  Processed 63/1435 audio samples 10b01Aa.wav
# male
# fearful
#  Processed 64/1435 audio samples 09a05Ed.wav
# female
# disgust
#  Processed 65/1435 audio samples 03b10Wb.wav
# male
# angry
#  Processed 66/1435 audio samples 10a07Ta.wav
# male
# sad
#  Processed 67/1435 audio samples 08a05Nb.wav
# female
# neutral
#  Processed 68/1435 audio samples 10a04Fd.wav
# male
# happy
#  Processed 69/1435 audio samples 03a05Nd.wav
# male
# neutral
#  Processed 70/1435 audio samples 11a01Aa.wav
# male
# fearful
#  Processed 71/1435 audio samples 11a04Fd.wav
# male
# happy
#  Processed 72/1435 audio samples 10b02Aa.wav
# male
# fearful
#  Processed 73/1435 audio samples 03a05Wb.wav
# male
# angry
#  Processed 74/1435 audio samples 10a07Wb.wav
# male
# angry
#  Processed 75/1435 audio samples 09b09Nd.wav
# female
# neutral
#  Processed 76/1435 audio samples 10a02Wa.wav
# male
# angry
#  Processed 77/1435 audio samples 10a07La.wav
# male
# boredom
#  Processed 78/1435 audio samples 03b10Na.wav
# male
# neutral
#  Processed 79/1435 audio samples 09a07Wb.wav
# female
# angry
#  Processed 80/1435 audio samples 10a02Fa.wav
# male
# happy
#  Processed 81/1435 audio samples 11a01Nd.wav
# male
# neutral
#  Processed 82/1435 audio samples 10a05Tb.wav
# male
# sad
#  Processed 83/1435 audio samples 08a05Ta.wav
# female
# sad
#  Processed 84/1435 audio samples 09a04Fd.wav
# female
# happy
#  Processed 85/1435 audio samples 03b02Na.wav
# male
# neutral
#  Processed 86/1435 audio samples 08a02Tb.wav
# female
# sad
#  Processed 87/1435 audio samples 03a04Lc.wav
# male
# boredom
#  Processed 88/1435 audio samples 08a04Wc.wav
# female
# angry
#  Processed 89/1435 audio samples 08b01Aa.wav
# female
# fearful
#  Processed 90/1435 audio samples 09a02Wb.wav
# female
# angry
#  Processed 91/1435 audio samples 10b09Ad.wav
# male
# fearful
#  Processed 92/1435 audio samples 10a01Ac.wav
# male
# fearful
#  Processed 93/1435 audio samples 09b09Wa.wav
# female
# angry
#  Processed 94/1435 audio samples 11a01Ld.wav
# male
# boredom
#  Processed 95/1435 audio samples 08a04Nc.wav
# female
# neutral
#  Processed 96/1435 audio samples 08a02Ab.wav
# female
# fearful
#  Processed 97/1435 audio samples 08a05Lc.wav
# female
# boredom
#  Processed 98/1435 audio samples 10b10Fc.wav
# male
# happy
#  Processed 99/1435 audio samples 08b09Wc.wav
# female
# angry
#  Processed 100/1435 audio samples 11a02Ld.wav
# male
# boredom
#  Processed 101/1435 audio samples 08b10Nc.wav
# female
# neutral
#  Processed 102/1435 audio samples 10a01Nb.wav
# male
# neutral
#  Processed 103/1435 audio samples 03b03Wc.wav
# male
# angry
#  Processed 104/1435 audio samples 03b01Td.wav
# male
# sad
#  Processed 105/1435 audio samples 09b10Nd.wav
# female
# neutral
#  Processed 106/1435 audio samples 11a02Fb.wav
# male
# happy
#  Processed 107/1435 audio samples 08a07La.wav
# female
# boredom
#  Processed 108/1435 audio samples 03b03Nb.wav
# male
# neutral
#  Processed 109/1435 audio samples 09a07Wd.wav
# female
# angry
#  Processed 110/1435 audio samples 10b01Fa.wav
# male
# happy
#  Processed 111/1435 audio samples 09a05Lc.wav
# female
# boredom
#  Processed 112/1435 audio samples 09a04Wa.wav
# female
# angry
#  Processed 113/1435 audio samples 08b09Fd.wav
# female
# happy
#  Processed 114/1435 audio samples 11a02Tc.wav
# male
# sad
#  Processed 115/1435 audio samples 09a02La.wav
# female
# boredom
#  Processed 116/1435 audio samples 10a05Aa.wav
# male
# fearful
#  Processed 117/1435 audio samples 09b03Wb.wav
# female
# angry
#  Processed 118/1435 audio samples 09a01Ea.wav
# female
# disgust
#  Processed 119/1435 audio samples 09a05Wc.wav
# female
# angry
#  Processed 120/1435 audio samples 03b01Lb.wav
# male
# boredom
#  Processed 121/1435 audio samples 09a05Wb.wav
# female
# angry
#  Processed 122/1435 audio samples 08b02Ff.wav
# female
# happy
#  Processed 123/1435 audio samples 08a04La.wav
# female
# boredom
#  Processed 124/1435 audio samples 03b10Wc.wav
# male
# angry
#  Processed 125/1435 audio samples 08b01Lb.wav
# female
# boredom
#  Processed 126/1435 audio samples 10b02La.wav
# male
# boredom
#  Processed 127/1435 audio samples 03b02Tb.wav
# male
# sad
#  Processed 128/1435 audio samples 03b09La.wav
# male
# boredom
#  Processed 129/1435 audio samples 03a05Aa.wav
# male
# fearful
#  Processed 130/1435 audio samples 09b03Fa.wav
# female
# happy
#  Processed 131/1435 audio samples 03a05Wa.wav
# male
# angry
#  Processed 132/1435 audio samples 03b03Tc.wav
# male
# sad
#  Processed 133/1435 audio samples 08b10Wa.wav
# female
# angry
#  Processed 134/1435 audio samples 08a05Wa.wav
# female
# angry
#  Processed 135/1435 audio samples 08b03Lc.wav
# female
# boredom
#  Processed 136/1435 audio samples 08a01Wc.wav
# female
# angry
#  Processed 137/1435 audio samples 09b03Lb.wav
# female
# boredom
#  Processed 138/1435 audio samples 10b01Lb.wav
# male
# boredom
#  Processed 139/1435 audio samples 09b10Aa.wav
# female
# fearful
#  Processed 140/1435 audio samples 09a05Nb.wav
# female
# neutral
#  Processed 141/1435 audio samples 08b02Nb.wav
# female
# neutral
#  Processed 142/1435 audio samples 03b02Wb.wav
# male
# angry
#  Processed 143/1435 audio samples 08b02Wd.wav
# female
# angry
#  Processed 144/1435 audio samples 08a05Fe.wav
# female
# happy
#  Processed 145/1435 audio samples 08b03Nb.wav
# female
# neutral
#  Processed 146/1435 audio samples 08a01Ab.wav
# female
# fearful
#  Processed 147/1435 audio samples 03a05Tc.wav
# male
# sad
#  Processed 148/1435 audio samples 08a02La.wav
# female
# boredom
#  Processed 149/1435 audio samples 09b01Wb.wav
# female
# angry
#  Processed 150/1435 audio samples 03b01Fa.wav
# male
# happy
#  Processed 151/1435 audio samples 09a01Wb.wav
# female
# angry
#  Processed 152/1435 audio samples 08b10Tc.wav
# female
# sad
#  Processed 153/1435 audio samples 10b01Ea.wav
# male
# disgust
#  Processed 154/1435 audio samples 08b10Fd.wav
# female
# happy
#  Processed 155/1435 audio samples 10b09Wb.wav
# male
# angry
#  Processed 156/1435 audio samples 08b09Tb.wav
# female
# sad
#  Processed 157/1435 audio samples 10a05Wb.wav
# male
# angry
#  Processed 158/1435 audio samples 11a05Ad.wav
# male
# fearful
#  Processed 159/1435 audio samples 03b09Nc.wav
# male
# neutral
#  Processed 160/1435 audio samples 03a07La.wav
# male
# boredom
#  Processed 161/1435 audio samples 09a01Nb.wav
# female
# neutral
#  Processed 162/1435 audio samples 03b10Nc.wav
# male
# neutral
#  Processed 163/1435 audio samples 10b03La.wav
# male
# boredom
#  Processed 164/1435 audio samples 08a01Fd.wav
# female
# happy
#  Processed 165/1435 audio samples 03b01Nb.wav
# male
# neutral
#  Processed 166/1435 audio samples 10b09Lb.wav
# male
# boredom
#  Processed 167/1435 audio samples 10a02Na.wav
# male
# neutral
#  Processed 168/1435 audio samples 08b01Na.wav
# female
# neutral
#  Processed 169/1435 audio samples 11a05Lc.wav
# male
# boredom
#  Processed 170/1435 audio samples 08b01Fd.wav
# female
# happy
#  Processed 171/1435 audio samples 09b02Na.wav
# female
# neutral
#  Processed 172/1435 audio samples 09b03Ed.wav
# female
# disgust
#  Processed 173/1435 audio samples 08b10La.wav
# female
# boredom
#  Processed 174/1435 audio samples 08b10Aa.wav
# female
# fearful
#  Processed 175/1435 audio samples 03a07Fb.wav
# male
# happy
#  Processed 176/1435 audio samples 09b10Wa.wav
# female
# angry
#  Processed 177/1435 audio samples 08b09Ab.wav
# female
# fearful
#  Processed 178/1435 audio samples 08a02Na.wav
# female
# neutral
#  Processed 179/1435 audio samples 10b10Lc.wav
# male
# boredom
#  Processed 180/1435 audio samples 08a01Wa.wav
# female
# angry
#  Processed 181/1435 audio samples 09b09Ea.wav
# female
# disgust
#  Processed 182/1435 audio samples 09b02Tb.wav
# female
# sad
#  Processed 183/1435 audio samples 03b09Wa.wav
# male
# angry
#  Processed 184/1435 audio samples 10b02Wb.wav
# male
# angry
#  Processed 185/1435 audio samples 10a02Lb.wav
# male
# boredom
#  Processed 186/1435 audio samples 10a02Ab.wav
# male
# fearful
#  Processed 187/1435 audio samples 10b03Wb.wav
# male
# angry
#  Processed 188/1435 audio samples 03b10Ec.wav
# male
# disgust
#  Processed 189/1435 audio samples 08b03Wd.wav
# female
# angry
#  Processed 190/1435 audio samples 11a01Ab.wav
# male
# fearful
#  Processed 191/1435 audio samples 03b01Wc.wav
# male
# angry
#  Processed 192/1435 audio samples 09b01Na.wav
# female
# neutral
#  Processed 193/1435 audio samples 08b01Fe.wav
# female
# happy
#  Processed 194/1435 audio samples 08a01Lc.wav
# female
# boredom
#  Processed 195/1435 audio samples 03a02Wc.wav
# male
# angry
#  Processed 196/1435 audio samples 08a04Ff.wav
# female
# happy
#  Processed 197/1435 audio samples 03a04Ta.wav
# male
# sad
#  Processed 198/1435 audio samples 10b10Wa.wav
# male
# angry
#  Processed 199/1435 audio samples 10a04Wb.wav
# male
# angry
#  Processed 200/1435 audio samples 08b09Lc.wav
# female
# boredom
#  Processed 201/1435 audio samples 08b09Nb.wav
# female
# neutral
#  Processed 202/1435 audio samples 08a01Na.wav
# female
# neutral
#  Processed 203/1435 audio samples 03b02Aa.wav
# male
# fearful
#  Processed 204/1435 audio samples 11a04Ac.wav
# male
# fearful
#  Processed 205/1435 audio samples 10a04Wa.wav
# male
# angry
#  Processed 206/1435 audio samples 08b09Wa.wav
# female
# angry
#  Processed 207/1435 audio samples 13a02Ad.wav
# female
# fearful
#  Processed 208/1435 audio samples 13a04Fc.wav
# female
# happy
#  Processed 209/1435 audio samples 13b01Fc.wav
# female
# happy
#  Processed 210/1435 audio samples 14b09Ac.wav
# female
# fearful
#  Processed 211/1435 audio samples 13a07Na.wav
# female
# neutral
#  Processed 212/1435 audio samples 14a02Wc.wav
# female
# angry
#  Processed 213/1435 audio samples 13b02Wa.wav
# female
# angry
#  Processed 214/1435 audio samples 13a07Wb.wav
# female
# angry
#  Processed 215/1435 audio samples 13a01Nb.wav
# female
# neutral
#  Processed 216/1435 audio samples 11b10Wa.wav
# male
# angry
#  Processed 217/1435 audio samples 12a02Ec.wav
# male
# disgust
#  Processed 218/1435 audio samples 12a05Wb.wav
# male
# angry
#  Processed 219/1435 audio samples 13a04Wc.wav
# female
# angry
#  Processed 220/1435 audio samples 13a01Ea.wav
# female
# disgust
#  Processed 221/1435 audio samples 14a05Lb.wav
# female
# boredom
#  Processed 222/1435 audio samples 13a02Ec.wav
# female
# disgust
#  Processed 223/1435 audio samples 14a04Lb.wav
# female
# boredom
#  Processed 224/1435 audio samples 14b01Wc.wav
# female
# angry
#  Processed 225/1435 audio samples 13b09Fb.wav
# female
# happy
#  Processed 226/1435 audio samples 13a05Nb.wav
# female
# neutral
#  Processed 227/1435 audio samples 13a05Aa.wav
# female
# fearful
#  Processed 228/1435 audio samples 11b03Nb.wav
# male
# neutral
#  Processed 229/1435 audio samples 13a07Tc.wav
# female
# sad
#  Processed 230/1435 audio samples 13b03Na.wav
# female
# neutral
#  Processed 231/1435 audio samples 12b02Na.wav
# male
# neutral
#  Processed 232/1435 audio samples 12b10Wa.wav
# male
# angry
#  Processed 233/1435 audio samples 14a07Ld.wav
# female
# boredom
#  Processed 234/1435 audio samples 13b01Ec.wav
# female
# disgust
#  Processed 235/1435 audio samples 14b03Lb.wav
# female
# boredom
#  Processed 236/1435 audio samples 12a01Wc.wav
# male
# angry
#  Processed 237/1435 audio samples 14a04Wb.wav
# female
# angry
#  Processed 238/1435 audio samples 12b02Wb.wav
# male
# angry
#  Processed 239/1435 audio samples 13b01Wa.wav
# female
# angry
#  Processed 240/1435 audio samples 13b03Wc.wav
# female
# angry
#  Processed 241/1435 audio samples 13b01Ld.wav
# female
# boredom
#  Processed 242/1435 audio samples 13a02Wa.wav
# female
# angry
#  Processed 243/1435 audio samples 13b02Fb.wav
# female
# happy
#  Processed 244/1435 audio samples 13b10La.wav
# female
# boredom
#  Processed 245/1435 audio samples 12b02Wa.wav
# male
# angry
#  Processed 246/1435 audio samples 11b01Nc.wav
# male
# neutral
#  Processed 247/1435 audio samples 14a04Wc.wav
# female
# angry
#  Processed 248/1435 audio samples 13a05Wa.wav
# female
# angry
#  Processed 249/1435 audio samples 11b09Ad.wav
# male
# fearful
#  Processed 250/1435 audio samples 11a05Na.wav
# male
# neutral
#  Processed 251/1435 audio samples 12a04Wc.wav
# male
# angry
#  Processed 252/1435 audio samples 14a05Na.wav
# female
# neutral
#  Processed 253/1435 audio samples 12a02Wc.wav
# male
# angry
#  Processed 254/1435 audio samples 14a01Aa.wav
# female
# fearful
#  Processed 255/1435 audio samples 14a07Fd.wav
# female
# happy
#  Processed 256/1435 audio samples 14a07Tc.wav
# female
# sad
#  Processed 257/1435 audio samples 12a05Ta.wav
# male
# sad
#  Processed 258/1435 audio samples 13b01Nc.wav
# female
# neutral
#  Processed 259/1435 audio samples 13a04Lb.wav
# female
# boredom
#  Processed 260/1435 audio samples 12a05Lb.wav
# male
# boredom
#  Processed 261/1435 audio samples 14a05Wb.wav
# female
# angry
#  Processed 262/1435 audio samples 14b02Tc.wav
# female
# sad
#  Processed 263/1435 audio samples 13a07Lb.wav
# female
# boredom
#  Processed 264/1435 audio samples 11b10Td.wav
# male
# sad
#  Processed 265/1435 audio samples 13a01Ec.wav
# female
# disgust
#  Processed 266/1435 audio samples 14a01Ea.wav
# female
# disgust
#  Processed 267/1435 audio samples 13a02Fa.wav
# female
# happy
#  Processed 268/1435 audio samples 14b01Fc.wav
# female
# happy
#  Processed 269/1435 audio samples 14a05Tc.wav
# female
# sad
#  Processed 270/1435 audio samples 12b09Td.wav
# male
# sad
#  Processed 271/1435 audio samples 14a05Ta.wav
# female
# sad
#  Processed 272/1435 audio samples 13b09Na.wav
# female
# neutral
#  Processed 273/1435 audio samples 14a07Aa.wav
# female
# fearful
#  Processed 274/1435 audio samples 13a02Lc.wav
# female
# boredom
#  Processed 275/1435 audio samples 14b02Fb.wav
# female
# happy
#  Processed 276/1435 audio samples 14a02Wa.wav
# female
# angry
#  Processed 277/1435 audio samples 11b01Fc.wav
# male
# happy
#  Processed 278/1435 audio samples 11b09Wa.wav
# male
# angry
#  Processed 279/1435 audio samples 14a04Tc.wav
# female
# sad
#  Processed 280/1435 audio samples 11b02Na.wav
# male
# neutral
#  Processed 281/1435 audio samples 12b02Wd.wav
# male
# angry
#  Processed 282/1435 audio samples 12a07La.wav
# male
# boredom
#  Processed 283/1435 audio samples 13b03Ed.wav
# female
# disgust
#  Processed 284/1435 audio samples 14b02Na.wav
# female
# neutral
#  Processed 285/1435 audio samples 13a05Lc.wav
# female
# boredom
#  Processed 286/1435 audio samples 13a02Ta.wav
# female
# sad
#  Processed 287/1435 audio samples 12a01Fb.wav
# male
# happy
#  Processed 288/1435 audio samples 11b01Lb.wav
# male
# boredom
#  Processed 289/1435 audio samples 14b09Ea.wav
# female
# disgust
#  Processed 290/1435 audio samples 14a04Tb.wav
# female
# sad
#  Processed 291/1435 audio samples 11b02Fd.wav
# male
# happy
#  Processed 292/1435 audio samples 11b10Ae.wav
# male
# fearful
#  Processed 293/1435 audio samples 13b03Lb.wav
# female
# boredom
#  Processed 294/1435 audio samples 14b03Ta.wav
# female
# sad
#  Processed 295/1435 audio samples 14a04Ed.wav
# female
# disgust
#  Processed 296/1435 audio samples 11b03Td.wav
# male
# sad
#  Processed 297/1435 audio samples 14a05Aa.wav
# female
# fearful
#  Processed 298/1435 audio samples 11a07Wc.wav
# male
# angry
#  Processed 299/1435 audio samples 14b03Ed.wav
# female
# disgust
#  Processed 300/1435 audio samples 11a07Ac.wav
# male
# fearful
#  Processed 301/1435 audio samples 11b09Na.wav
# male
# neutral
#  Processed 302/1435 audio samples 13b09Wa.wav
# female
# angry
#  Processed 303/1435 audio samples 11b10Ad.wav
# male
# fearful
#  Processed 304/1435 audio samples 14b02Wd.wav
# female
# angry
#  Processed 305/1435 audio samples 14a04Aa.wav
# female
# fearful
#  Processed 306/1435 audio samples 14a02Fd.wav
# female
# happy
#  Processed 307/1435 audio samples 11b03Lc.wav
# male
# boredom
#  Processed 308/1435 audio samples 13b03Fd.wav
# female
# happy
#  Processed 309/1435 audio samples 13b10Wa.wav
# female
# angry
#  Processed 310/1435 audio samples 12a02Wa.wav
# male
# angry
#  Processed 311/1435 audio samples 11b02Ab.wav
# male
# fearful
#  Processed 312/1435 audio samples 13b02Nb.wav
# female
# neutral
#  Processed 313/1435 audio samples 13a04Ac.wav
# female
# fearful
#  Processed 314/1435 audio samples 13a07Fd.wav
# female
# happy
#  Processed 315/1435 audio samples 12b01Wa.wav
# male
# angry
#  Processed 316/1435 audio samples 14b03Wb.wav
# female
# angry
#  Processed 317/1435 audio samples 13a01Wb.wav
# female
# angry
#  Processed 318/1435 audio samples 14a01Wc.wav
# female
# angry
#  Processed 319/1435 audio samples 12a02Ac.wav
# male
# fearful
#  Processed 320/1435 audio samples 14b01Fa.wav
# female
# happy
#  Processed 321/1435 audio samples 13b09Fc.wav
# female
# happy
#  Processed 322/1435 audio samples 11b03Fc.wav
# male
# happy
#  Processed 323/1435 audio samples 14a07Na.wav
# female
# neutral
#  Processed 324/1435 audio samples 14a07Lc.wav
# female
# boredom
#  Processed 325/1435 audio samples 13a01Lb.wav
# female
# boredom
#  Processed 326/1435 audio samples 14b01Eb.wav
# female
# disgust
#  Processed 327/1435 audio samples 13b03Td.wav
# female
# sad
#  Processed 328/1435 audio samples 13a01Fd.wav
# female
# happy
#  Processed 329/1435 audio samples 11b09Fd.wav
# male
# happy
#  Processed 330/1435 audio samples 14b03Ad.wav
# female
# fearful
#  Processed 331/1435 audio samples 13b10Nc.wav
# female
# neutral
#  Processed 332/1435 audio samples 11b10Nc.wav
# male
# neutral
#  Processed 333/1435 audio samples 11b01Eb.wav
# male
# disgust
#  Processed 334/1435 audio samples 11b02Wb.wav
# male
# angry
#  Processed 335/1435 audio samples 13a04Ta.wav
# female
# sad
#  Processed 336/1435 audio samples 14a02Tb.wav
# female
# sad
#  Processed 337/1435 audio samples 11a07Ld.wav
# male
# boredom
#  Processed 338/1435 audio samples 14b01Na.wav
# female
# neutral
#  Processed 339/1435 audio samples 12a05Ab.wav
# male
# fearful
#  Processed 340/1435 audio samples 13b09Ec.wav
# female
# disgust
#  Processed 341/1435 audio samples 12b02Ad.wav
# male
# fearful
#  Processed 342/1435 audio samples 13b10Ec.wav
# female
# disgust
#  Processed 343/1435 audio samples 13b10Fa.wav
# female
# happy
#  Processed 344/1435 audio samples 14a02Ab.wav
# female
# fearful
#  Processed 345/1435 audio samples 11b09Td.wav
# male
# sad
#  Processed 346/1435 audio samples 14a05Fa.wav
# female
# happy
#  Processed 347/1435 audio samples 13b10Wc.wav
# female
# angry
#  Processed 348/1435 audio samples 12b09Ac.wav
# male
# fearful
#  Processed 349/1435 audio samples 12a01Nb.wav
# male
# neutral
#  Processed 350/1435 audio samples 12b10Ac.wav
# male
# fearful
#  Processed 351/1435 audio samples 11b02Td.wav
# male
# sad
#  Processed 352/1435 audio samples 12a05Nd.wav
# male
# neutral
#  Processed 353/1435 audio samples 12b03Ta.wav
# male
# sad
#  Processed 354/1435 audio samples 11a07Ta.wav
# male
# sad
#  Processed 355/1435 audio samples 11b01Ab.wav
# male
# fearful
#  Processed 356/1435 audio samples 12b10Ld.wav
# male
# boredom
#  Processed 357/1435 audio samples 12a07Wa.wav
# male
# angry
#  Processed 358/1435 audio samples 13a05Ea.wav
# female
# disgust
#  Processed 359/1435 audio samples 13b09Ab.wav
# female
# fearful
#  Processed 360/1435 audio samples 14b02Wb.wav
# female
# angry
#  Processed 361/1435 audio samples 13b02Lc.wav
# female
# boredom
#  Processed 362/1435 audio samples 14a02Nc.wav
# female
# neutral
#  Processed 363/1435 audio samples 12b09Wc.wav
# male
# angry
#  Processed 364/1435 audio samples 14a05Wa.wav
# female
# angry
#  Processed 365/1435 audio samples 11b10Ld.wav
# male
# boredom
#  Processed 366/1435 audio samples 12b03La.wav
# male
# boredom
#  Processed 367/1435 audio samples 12a02Nb.wav
# male
# neutral
#  Processed 368/1435 audio samples 14a07Wc.wav
# female
# angry
#  Processed 369/1435 audio samples 14a02La.wav
# female
# boredom
#  Processed 370/1435 audio samples 11a05Wd.wav
# male
# angry
#  Processed 371/1435 audio samples 11b01Wd.wav
# male
# angry
#  Processed 372/1435 audio samples 12a07Ac.wav
# male
# fearful
#  Processed 373/1435 audio samples 14a05Fb.wav
# female
# happy
#  Processed 374/1435 audio samples 12b01Ta.wav
# male
# sad
#  Processed 375/1435 audio samples 13b09La.wav
# female
# boredom
#  Processed 376/1435 audio samples 14a01Wa.wav
# female
# angry
#  Processed 377/1435 audio samples 11b03Wb.wav
# male
# angry
#  Processed 378/1435 audio samples 11a05Td.wav
# male
# sad
#  Processed 379/1435 audio samples 13a05Tc.wav
# female
# sad
#  Processed 380/1435 audio samples 13b03Ac.wav
# female
# fearful
#  Processed 381/1435 audio samples 14b01Ac.wav
# female
# fearful
#  Processed 382/1435 audio samples 13a02Nc.wav
# female
# neutral
#  Processed 383/1435 audio samples 12a01Lb.wav
# male
# boredom
#  Processed 384/1435 audio samples 14a01Na.wav
# female
# neutral
#  Processed 385/1435 audio samples 12b02Ea.wav
# male
# disgust
#  Processed 386/1435 audio samples 14a05Ac.wav
# female
# fearful
#  Processed 387/1435 audio samples 13b01Ab.wav
# female
# fearful
#  Processed 388/1435 audio samples 14a01Ac.wav
# female
# fearful
#  Processed 389/1435 audio samples 11b09Ld.wav
# male
# boredom
#  Processed 390/1435 audio samples 14a07Eb.wav
# female
# disgust
#  Processed 391/1435 audio samples 14b02Aa.wav
# female
# fearful
#  Processed 392/1435 audio samples 12b02Fb.wav
# male
# happy
#  Processed 393/1435 audio samples 13a05Wc.wav
# female
# angry
#  Processed 394/1435 audio samples 13a01Ac.wav
# female
# fearful
#  Processed 395/1435 audio samples 14a02Ea.wav
# female
# disgust
#  Processed 396/1435 audio samples 11b03Wa.wav
# male
# angry
#  Processed 397/1435 audio samples 16a04Ab.wav
# female
# fearful
#  Processed 398/1435 audio samples 15a07Fb.wav
# male
# happy
#  Processed 399/1435 audio samples 16b10Eb.wav
# female
# disgust
#  Processed 400/1435 audio samples 15b10Nc.wav
# male
# neutral
#  Processed 401/1435 audio samples 16a01Lb.wav
# female
# boredom
#  Processed 402/1435 audio samples 16b09Fb.wav
# female
# happy
#  Processed 403/1435 audio samples 15b02Wc.wav
# male
# angry
#  Processed 404/1435 audio samples 16b02Wb.wav
# female
# angry
#  Processed 405/1435 audio samples 15a02Ta.wav
# male
# sad
#  Processed 406/1435 audio samples 15a04Fd.wav
# male
# happy
#  Processed 407/1435 audio samples 16a04Fa.wav
# female
# happy
#  Processed 408/1435 audio samples 16b09La.wav
# female
# boredom
#  Processed 409/1435 audio samples 15a02Wb.wav
# male
# angry
#  Processed 410/1435 audio samples 16a07Ea.wav
# female
# disgust
#  Processed 411/1435 audio samples 15a05Fb.wav
# male
# happy
#  Processed 412/1435 audio samples 15b03Aa.wav
# male
# fearful
#  Processed 413/1435 audio samples 16a02Lb.wav
# female
# boredom
#  Processed 414/1435 audio samples 15a05Na.wav
# male
# neutral
#  Processed 415/1435 audio samples 15a07Ac.wav
# male
# fearful
#  Processed 416/1435 audio samples 16a05Ea.wav
# female
# disgust
#  Processed 417/1435 audio samples 14b09Wc.wav
# female
# angry
#  Processed 418/1435 audio samples 16b01Aa.wav
# female
# fearful
#  Processed 419/1435 audio samples 16b01La.wav
# female
# boredom
#  Processed 420/1435 audio samples 15a02Na.wav
# male
# neutral
#  Processed 421/1435 audio samples 16b03Nb.wav
# female
# neutral
#  Processed 422/1435 audio samples 16a07Nb.wav
# female
# neutral
#  Processed 423/1435 audio samples 15b10Ac.wav
# male
# fearful
#  Processed 424/1435 audio samples 16b03Wb.wav
# female
# angry
#  Processed 425/1435 audio samples 15a05Lb.wav
# male
# boredom
#  Processed 426/1435 audio samples 15b02Lb.wav
# male
# boredom
#  Processed 427/1435 audio samples 16a07Wa.wav
# female
# angry
#  Processed 428/1435 audio samples 15b09La.wav
# male
# boredom
#  Processed 429/1435 audio samples 16b10Wa.wav
# female
# angry
#  Processed 430/1435 audio samples 14b10Nb.wav
# female
# neutral
#  Processed 431/1435 audio samples 16b01Fa.wav
# female
# happy
#  Processed 432/1435 audio samples 15a01La.wav
# male
# boredom
#  Processed 433/1435 audio samples 14b09Td.wav
# female
# sad
#  Processed 434/1435 audio samples 16a01Ec.wav
# female
# disgust
#  Processed 435/1435 audio samples 16a05Wc.wav
# female
# angry
#  Processed 436/1435 audio samples 15b09Nb.wav
# male
# neutral
#  Processed 437/1435 audio samples 15b10Nb.wav
# male
# neutral
#  Processed 438/1435 audio samples 15b02Tc.wav
# male
# sad
#  Processed 439/1435 audio samples 15b01Na.wav
# male
# neutral
#  Processed 440/1435 audio samples 16a04La.wav
# female
# boredom
#  Processed 441/1435 audio samples 14b10Wc.wav
# female
# angry
#  Processed 442/1435 audio samples 16a07La.wav
# female
# boredom
#  Processed 443/1435 audio samples 15a07Eb.wav
# male
# disgust
#  Processed 444/1435 audio samples 15b02Wa.wav
# male
# angry
#  Processed 445/1435 audio samples 15a04Wb.wav
# male
# angry
#  Processed 446/1435 audio samples 15b03Tc.wav
# male
# sad
#  Processed 447/1435 audio samples 16b10Lb.wav
# female
# boredom
#  Processed 448/1435 audio samples 15a04Ac.wav
# male
# fearful
#  Processed 449/1435 audio samples 16a05Ab.wav
# female
# fearful
#  Processed 450/1435 audio samples 16a01Nc.wav
# female
# neutral
#  Processed 451/1435 audio samples 16b01Wa.wav
# female
# angry
#  Processed 452/1435 audio samples 16b03Fa.wav
# female
# happy
#  Processed 453/1435 audio samples 15b02Nd.wav
# male
# neutral
#  Processed 454/1435 audio samples 16a02Wb.wav
# female
# angry
#  Processed 455/1435 audio samples 16a05La.wav
# female
# boredom
#  Processed 456/1435 audio samples 15b03Nb.wav
# male
# neutral
#  Processed 457/1435 audio samples 15a01Wa.wav
# male
# angry
#  Processed 458/1435 audio samples 16b01Lc.wav
# female
# boredom
#  Processed 459/1435 audio samples 15b01Ec.wav
# male
# disgust
#  Processed 460/1435 audio samples 15b03Wa.wav
# male
# angry
#  Processed 461/1435 audio samples 15a02Ac.wav
# male
# fearful
#  Processed 462/1435 audio samples 16a05Tb.wav
# female
# sad
#  Processed 463/1435 audio samples 16a07Lb.wav
# female
# boredom
#  Processed 464/1435 audio samples 16a07Fa.wav
# female
# happy
#  Processed 465/1435 audio samples 15b10Wa.wav
# male
# angry
#  Processed 466/1435 audio samples 16b09Ab.wav
# female
# fearful
#  Processed 467/1435 audio samples 16a01Fc.wav
# female
# happy
#  Processed 468/1435 audio samples 14b09Fc.wav
# female
# happy
#  Processed 469/1435 audio samples 15a05Eb.wav
# male
# disgust
#  Processed 470/1435 audio samples 16b01Wb.wav
# female
# angry
#  Processed 471/1435 audio samples 16b03La.wav
# female
# boredom
#  Processed 472/1435 audio samples 15a07Nc.wav
# male
# neutral
#  Processed 473/1435 audio samples 15a02Ea.wav
# male
# disgust
#  Processed 474/1435 audio samples 15b10Lc.wav
# male
# boredom
#  Processed 475/1435 audio samples 16b10Tb.wav
# female
# sad
#  Processed 476/1435 audio samples 16a01Tb.wav
# female
# sad
#  Processed 477/1435 audio samples 15a04Ab.wav
# male
# fearful
#  Processed 478/1435 audio samples 14b10Tc.wav
# female
# sad
#  Processed 479/1435 audio samples 16a04Wc.wav
# female
# angry
#  Processed 480/1435 audio samples 16b09Eb.wav
# female
# disgust
#  Processed 481/1435 audio samples 15b09Wb.wav
# male
# angry
#  Processed 482/1435 audio samples 16b03Ad.wav
# female
# fearful
#  Processed 483/1435 audio samples 16b02Aa.wav
# female
# fearful
#  Processed 484/1435 audio samples 16b03Ta.wav
# female
# sad
#  Processed 485/1435 audio samples 16a04Nc.wav
# female
# neutral
#  Processed 486/1435 audio samples 16a02Nb.wav
# female
# neutral
#  Processed 487/1435 audio samples 15a04Nc.wav
# male
# neutral
#  Processed 488/1435 audio samples 15a04Wa.wav
# male
# angry
#  Processed 489/1435 audio samples 16a02Ec.wav
# female
# disgust
#  Processed 490/1435 audio samples 15b03Wb.wav
# male
# angry
#  Processed 491/1435 audio samples 16b01Tb.wav
# female
# sad
#  Processed 492/1435 audio samples 16b02Eb.wav
# female
# disgust
#  Processed 493/1435 audio samples 16a04Wb.wav
# female
# angry
#  Processed 494/1435 audio samples 16b10Aa.wav
# female
# fearful
#  Processed 495/1435 audio samples 16a02Tc.wav
# female
# sad
#  Processed 496/1435 audio samples 16b10Td.wav
# female
# sad
#  Processed 497/1435 audio samples 16b09Wb.wav
# female
# angry
#  Processed 498/1435 audio samples 15a05Wa.wav
# male
# angry
#  Processed 499/1435 audio samples 15b03Lc.wav
# male
# boredom
#  Processed 500/1435 audio samples 15a02La.wav
# male
# boredom
#  Processed 501/1435 audio samples 14b09Lb.wav
# female
# boredom
#  Processed 502/1435 audio samples 14b10Eb.wav
# female
# disgust
#  Processed 503/1435 audio samples 16b09Lb.wav
# female
# boredom
#  Processed 504/1435 audio samples 16a05Fc.wav
# female
# happy
#  Processed 505/1435 audio samples 15b01Lb.wav
# male
# boredom
#  Processed 506/1435 audio samples 15a01Ea.wav
# male
# disgust
#  Processed 507/1435 audio samples 16b10Fb.wav
# female
# happy
#  Processed 508/1435 audio samples 15a01Nb.wav
# male
# neutral
#  Processed 509/1435 audio samples 16b02Fd.wav
# female
# happy
#  Processed 510/1435 audio samples 16a07Td.wav
# female
# sad
#  Processed 511/1435 audio samples 15a02Wd.wav
# male
# angry
#  Processed 512/1435 audio samples 16a04Ea.wav
# female
# disgust
#  Processed 513/1435 audio samples 15b09Ta.wav
# male
# sad
#  Processed 514/1435 audio samples 15b09Fa.wav
# male
# happy
#  Processed 515/1435 audio samples 14b09Wa.wav
# female
# angry
#  Processed 516/1435 audio samples 16b01Eb.wav
# female
# disgust
#  Processed 517/1435 audio samples 16a02Ea.wav
# female
# disgust
#  Processed 518/1435 audio samples 16a07Fb.wav
# female
# happy
#  Processed 519/1435 audio samples 16a05Wb.wav
# female
# angry
#  Processed 520/1435 audio samples 16b03Ea.wav
# female
# disgust
#  Processed 521/1435 audio samples 16a01Wb.wav
# female
# angry
#  Processed 522/1435 audio samples 15b09Ac.wav
# male
# fearful
#  Processed 523/1435 audio samples 16a04Tc.wav
# female
# sad
#  Processed 524/1435 audio samples 16b10Wb.wav
# female
# angry
#  Processed 525/1435 audio samples 15b02Aa.wav
# male
# fearful
#  Processed 526/1435 audio samples 15b01Wc.wav
# male
# angry
#  Processed 527/1435 audio samples 14b10Ad.wav
# female
# fearful
#  Processed 528/1435 audio samples 16b02Lb.wav
# female
# boredom
#  Processed 529/1435 audio samples 14b10Lb.wav
# female
# boredom
#  Processed 530/1435 audio samples 15a07Fa.wav
# male
# happy
#  Processed 531/1435 audio samples 16a04Lc.wav
# female
# boredom
#  Processed 532/1435 audio samples 16b03Fd.wav
# female
# happy
#  Processed 533/1435 audio samples 15a01Fb.wav
# male
# happy
#  Processed 534/1435 audio samples 15a07Ld.wav
# male
# boredom
#  Processed 535/1435 audio samples

# %%
emotionsEmo
# Out:
# array(['sad', 'angry', 'neutral', 'happy', 'happy', 'neutral', 'angry',
#        'happy', 'angry', 'fearful', 'sad', 'happy', 'disgust', 'boredom',
#        'sad', 'angry', 'neutral', 'sad', 'angry', 'angry', 'disgust',
#        'angry', 'neutral', 'fearful', 'sad', 'angry', 'neutral', 'sad',
#        'disgust', 'happy', 'neutral', 'happy', 'fearful', 'boredom',
#        'angry', 'neutral', 'boredom', 'disgust', 'disgust', 'fearful',
#        'happy', 'sad', 'sad', 'neutral', 'happy', 'happy', 'neutral',
#        'angry', 'angry', 'neutral', 'happy', 'happy', 'neutral', 'sad',
#        'angry', 'neutral', 'happy', 'boredom', 'angry', 'sad', 'angry',
#        'sad', 'fearful', 'fearful', 'disgust', 'angry', 'sad', 'neutral',
#        'happy', 'neutral', 'fearful', 'happy', 'fearful', 'angry',
#        'angry', 'neutral', 'angry', 'boredom', 'neutral', 'angry',
#        'happy', 'neutral', 'sad', 'sad', 'happy', 'neutral', 'sad',
#        'boredom', 'angry', 'fearful', 'angry', 'fearful', 'fearful',
#        'angry', 'boredom', 'neutral', 'fearful', 'boredom', 'happy',
#        'angry', 'boredom', 'neutral', 'neutral', 'angry', 'sad',
#        'neutral', 'happy', 'boredom', 'neutral', 'angry', 'happy',
#        'boredom', 'angry', 'happy', 'sad', 'boredom', 'fearful', 'angry',
#        'disgust', 'angry', 'boredom', 'angry', 'happy', 'boredom',
#        'disgust', 'angry', 'fearful', 'happy', 'disgust', 'neutral',
#        'boredom', 'happy', 'angry', 'angry', 'sad', 'happy', 'happy',
#        'boredom', 'angry', 'disgust', 'happy', 'fearful', 'boredom',
#        'neutral', 'fearful', 'disgust', 'angry', 'fearful', 'boredom',
#        'neutral', 'neutral', 'neutral', 'fearful', 'angry', 'boredom',
#        'boredom', 'angry', 'boredom', 'angry', 'neutral', 'happy',
#        'boredom', 'sad', 'disgust', 'angry', 'neutral', 'neutral', 'sad',
#        'neutral', 'boredom', 'angry', 'boredom', 'disgust', 'angry',
#        'angry', 'sad', 'boredom', 'fearful', 'fearful', 'neutral',
#        'angry', 'happy', 'neutral', 'angry', 'boredom', 'neutral',
#        'angry', 'boredom', 'disgust', 'angry', 'fearful', 'sad',
#        'boredom', 'happy', 'angry', 'fearful', 'happy', 'happy',
#        'disgust', 'angry', 'boredom', 'neutral', 'disgust', 'boredom',
#        'sad', 'sad', 'fearful', 'sad', 'angry', 'disgust', 'angry',
#        'fearful', 'fearful', 'sad', 'neutral', 'neutral', 'neutral',
#        'angry', 'disgust', 'angry', 'sad', 'disgust', 'angry', 'fearful',
#        'sad', 'sad', 'angry', 'angry', 'boredom', 'boredom', 'boredom',
#        'disgust', 'boredom', 'happy', 'boredom', 'disgust', 'happy',
#        'neutral', 'happy', 'sad', 'angry', 'disgust', 'sad', 'happy',
#        'angry', 'disgust', 'disgust', 'happy', 'angry', 'disgust',
#        'angry', 'fearful', 'sad', 'angry', 'fearful', 'angry', 'fearful',
#        'boredom', 'boredom', 'happy', 'boredom', 'happy', 'happy',
#        'boredom'], dtype='<U7')

# %%
emotionsRAV
# Out:
# array(['neutral', 'calm', 'calm', ..., 'surprised', 'surprised',
#        'surprised'], dtype='<U9')

# %%
gendersRAV
# Out:
# array(['male', 'male', 'male', ..., 'female', 'female', 'female'],
#       dtype='<U6')

# %%
featuresEmo
# Out:
# array([[ 0.5961325 ,  0.63749754,  0.634938  , ..., -1.2263073 ,
#         -0.7201647 , -2.7202544 ],
#        [ 0.5643113 ,  0.6107583 ,  0.60358727, ...,  4.7540092 ,
#          2.5284324 ,  1.8524827 ],
#        [ 0.7206407 ,  0.72058344,  0.6172653 , ..., -2.4686177 ,
#         -1.8872681 , -2.4299705 ],
#        ...,
#        [ 0.54601145,  0.61947167,  0.5856754 , ..., -1.7832665 ,
#         -2.3068464 , -0.60499626],
#        [ 0.5423626 ,  0.5243873 ,  0.5786779 , ...,  2.0831852 ,
#          2.2477064 ,  0.5568028 ],
#        [ 0.5471817 ,  0.61319846,  0.69771284, ...,  1.550527  ,
#          0.7425212 ,  1.9258633 ]], dtype=float32)

# %%
newarr = emotionsEmo.astype('<U9')

# %%
emotionsBoth = np.append(emotionsRAV, emotionsEmo)
emotionsBoth
# Out:
# array(['neutral', 'calm', 'calm', ..., 'happy', 'happy', 'boredom'],
#       dtype='<U9')

# %%
emotionBoth = np.append(emotionsRAVDESS, emotionsDB)
emotionBoth
# Out:
# array([{'01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad', '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised'},
#        {'W': 'angry', 'L': 'boredom', 'E': 'disgust', 'A': 'fearful', 'F': 'happy', 'T': 'sad', 'N': 'neutral'}],
#       dtype=object)

# %%
featuresBoth = np.append(featuresRAV, featuresEmo)
featuresBoth
# Out:
# array([0.7404485, 0.754305 , 0.7944346, ..., 1.550527 , 0.7425212,
#        1.9258633], dtype=float32)

# %%
gendersBoth = np.append(gendersRAV, gendersEmo)
gendersBoth
# Out:
# array(['male', 'male', 'male', ..., 'female', 'male', 'male'], dtype='<U6')

# %% [markdown]
# Let's see what the features we extracted look like:

# %%
print(f'\nAudio samples represented: {featuresRAV.shape[0]}')
print(f'Numerical features extracted per sample: {featuresRAV.shape[1]}')
features_df = pd.DataFrame(featuresRAV) # make it pretty for display
features_df
# Out:
# Audio samples represented: 1436
# Numerical features extracted per sample: 180
#            0         1         2         3         4         5         6    \
# 0     0.740448  0.754305  0.794435  0.762357  0.750698  0.766440  0.760746
# 1     0.726023  0.721436  0.764594  0.816493  0.827641  0.780229  0.749252
# 2     0.773683  0.727492  0.710652  0.721363  0.749025  0.731665  0.724650
# 3     0.767892  0.773173  0.767299  0.761960  0.761103  0.746839  0.778872
# 4     0.777267  0.793841  0.807233  0.818620  0.833606  0.822753  0.791814
# ...        ...       ...       ...       ...       ...       ...       ...
# 1431  0.588133  0.597460  0.596384  0.593464  0.666774  0.688777  0.718830
# 1432  0.576196  0.577490  0.601407  0.622733  0.689206  0.693802  0.697040
# 1433  0.587758  0.581296  0.589146  0.589335  0.679954  0.728620  0.733394
# 1434  0.595904  0.600554  0.658190  0.674917  0.697147  0.724288  0.742043
# 1435  0.602016  0.571650  0.599537  0.643368  0.697178  0.713049  0.746994
#
#            7         8         9    ...       170       171       172  \
# 0     0.726902  0.810067  0.766189  ... -0.866881 -1.060410  0.038757
# 1     0.760399  0.779344  0.773309  ...  0.059573 -0.456057 -1.339846
# 2     0.723188  0.663878  0.652090  ... -0.714483  1.051868 -1.633774
# 3     0.795545  0.775900  0.725814  ... -1.091167  0.647568 -0.089051
# 4     0.768705  0.774642  0.754198  ...  0.532510  0.534745 -0.710745
# ...        ...       ...       ...  ...       ...       ...       ...
# 1431  0.716899  0.725043  0.725490  ... -1.326721  0.127296 -1.608462
# 1432  0.714656  0.739891  0.763690  ... -2.815177 -0.457626 -1.356481
# 1433  0.723432  0.688792  0.690408  ... -1.918090  0.865547  0.702857
# 1434  0.712220  0.703350  0.715665  ...  1.192626  1.787032 -1.094785
# 1435  0.747315  0.774400  0.727058  ... -1.746686  0.593727 -2.296972
#
#            173       174       175       176       177       178       179
# 0    -0.022301  0.706185  0.023566 -0.766235  0.265345  0.245783  0.296804
# 1     1.489148  1.432993 -1.302506 -2.171690 -0.322567  0.861442 -0.091942
# 2     1.882780  0.209125 -1.042170 -1.843544 -1.082108  0.660275 -1.818803
# 3     0.961230  0.134001  0.570485 -0.194870 -0.477599  0.527953 -0.329091
# 4     1.135705  2.566621 -0.451686 -0.611501  0.882686 -0.087778 -0.503762
# ...        ...       ...       ...       ...       ...       ...       ...
# 1431 -0.288018 -1.164090  1.638471  3.821139  3.532836  1.714969  2.329734
# 1432  0.151801  0.268593  0.690066  2.333960  2.456274  1.782303  2.342042
# 1433  1.310169 -0.615187  0.043197  2.727342  0.985024 -1.440582  0.054081
# 1434  0.225960 -1.665896  0.374356  2.352825  2.012068  0.037305  0.227573
# 1435  0.872351 -0.460926  0.402271  0.727774  0.365292  0.230503  2.165228
#
# [1436 rows x 180 columns]

# %% [markdown]
# We have a matrix of dim 1435 x 180. Looks good - 1435 audio samples, one per row, with a series of
# 180 numerical features for each sample.
#
# **Each of the 1435 feature arrays has 180 features composed of 12 chromagram pitch classes + 128 mel spectrogram bands + 40 MFC coefficients.**

# %% [markdown]
# Let's see the class balance of our dataset:

# %%
# plot emotions
plt.figure(figsize=(35,4))
plt.subplot(1,3,1)
#np.unique returns ordered list of unique elements and count of each element
emotion_list, count = np.unique(emotionsRAV, return_counts=True)
plt.bar(x=range(8), height=count)
plt.xticks(ticks=range(8), labels = [emotionRAV for emotionRAV in emotion_list],fontsize=10)
plt.xlabel('Emotion')
plt.tick_params(labelsize=16)
plt.ylabel('Number of Samples')
plt.show()

# %%
# plot emotions
plt.figure(figsize=(35,4))
plt.subplot(1,3,1)
#np.unique returns ordered list of unique elements and count of each element
emotion_list, count = np.unique(emotionsBoth, return_counts=True)
plt.bar(x=range(9), height=count)
plt.xticks(ticks=range(9), labels = [emotionBoth for emotionBoth in emotion_list],fontsize=10)
plt.xlabel('Emotion')
plt.tick_params(labelsize=16)
plt.ylabel('Number of Samples')
plt.show()

# %% [markdown]
# **Great, the classes appear to be balanced. That makes the task easier.** All emotions _except_ the neutral class have a "strong" intensity so there are half as many neutral samples. That might have an impact.

# %% [markdown]
# ### Feature Scaling
# To properly train most machine learning models on _most_ datasets, we first need to scale our features. **This is crucial for models which compute distances between data, and especially critical for DNNs**: If there is a difference in the variance of features simply because of their possible range of values, then a model will learn that the features with the greatest variance are the most important. However, **differences in the variance of unscaled features belonging to different and unknown distributions is an inappropriate measure of importance.** Let's check our features' properties:

# %%
# We would usually use df.describe(), but it provides a bit of a mess of information we don't need at the moment.
def print_features(df):
    # Check chromagram feature values
    features_df_chromagram = df.loc[:,:11]
    chroma_min = features_df_chromagram.min().min()
    chroma_max = features_df_chromagram.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    chroma_mean = features_df_chromagram.stack().mean()
    chroma_stdev = features_df_chromagram.stack().std()
    print(f'12 Chromagram features:       \
    min = {chroma_min:.3f}, \
    max = {chroma_max:.3f}, \
    mean = {chroma_mean:.3f}, \
    deviation = {chroma_stdev:.3f}')

    # Check mel spectrogram feature values
    features_df_melspectrogram = df.loc[:,12:139]
    mel_min = features_df_melspectrogram.min().min()
    mel_max = features_df_melspectrogram.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    mel_mean = features_df_melspectrogram.stack().mean()
    mel_stdev = features_df_melspectrogram.stack().std()
    print(f'\n128 Mel Spectrogram features: \
    min = {mel_min:.3f}, \
    max = {mel_max:.3f}, \
    mean = {mel_mean:.3f}, \
    deviation = {mel_stdev:.3f}')

    # Check MFCC feature values
    features_df_mfcc = df.loc[:,140:179]
    mfcc_min = features_df_mfcc.min().min()
    mfcc_max = features_df_mfcc.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    mfcc_mean = features_df_mfcc.stack().mean()
    mfcc_stdev = features_df_mfcc.stack().std()
    print(f'\n40 MFCC features:             \
    min = {mfcc_min:.3f},\
    max = {mfcc_max:.3f},\
    mean = {mfcc_mean:.3f},\
    deviation = {mfcc_stdev:.3f}')

print_features(features_df)
# Out:
# 12 Chromagram features:           min = 0.310,     max = 0.874,     mean = 0.666,     deviation = 0.085
#
# 128 Mel Spectrogram features:     min = 0.000,     max = 149.208,     mean = 0.187,     deviation = 1.599
#
# 40 MFCC features:                 min = -873.242,    max = 115.126,    mean = -14.627,    deviation = 98.497

# %% [markdown]
# **There's an obvious imbalance in the variance our features; Our features indeed belong to very different distributions:** our MFC coefficients' deviation is greater than the other features by orders of magnitude. That does not mean MFC coefficients are the most important feature, but rather it is a property of the way they are computed.  We will certainly need to scale this feature set.
#
# We have the choice of sklearn's StandardScaler and MinMaxScaler. Standard scaling subtracts the mean of each feature and divides it by the standard deviation of that feature, producing features with mean at zero and unit variance - that is, a variance and standard deviation of 1. Min-Max scaling transforms each feature to be within a bounded interval that we specify.
#
# In practice, **MinMax scaling is especially useful when we know our features should be in a bounded interval**, such as pixel values in [0,255], while **standard scaling is perhaps more practical for features with unknown distributions** because centering the features at zero-mean with a standard deviation of 1 means extreme values will have less of an impact on the model's learned weights, i.e. the model is less sensitive to outliers.
#
# We'll create MinMax scaled features as well so we can give them a try later on to confirm that standard scaling is better in the absence of knowledge on the appropriate distribution for a dataset's features.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

scaler = StandardScaler()
# keep our unscaled features just in case we need to process them alternatively
features_scaled = features
features_scaled = scaler.fit_transform(features_scaled)

scaler = MinMaxScaler()
# keep our unscaled features just in case we need to process them alternatively
features_minmax = features
features_minmax = scaler.fit_transform(features_minmax)

# %% [markdown]
# Make sure our features are properly scaled:

# %%
print('\033[1m'+'Standard Scaling:\n'+'\033[0m')
features_scaled_df = pd.DataFrame(features_scaled)
print_features(features_scaled_df)

print('\n\n\033[1m'+'MinMax Scaling:\n'+'\033[0m')
features_minmax_df = pd.DataFrame(features_minmax)
print_features(features_minmax_df)
# Out:
# Standard Scaling:
#
# 12 Chromagram features:           min = -3.957,     max = 2.645,     mean = -0.000,     deviation = 1.000
#
# 128 Mel Spectrogram features:     min = -0.475,     max = 36.493,     mean = 0.000,     deviation = 1.000
#
# 40 MFCC features:                 min = -4.210,    max = 6.242,    mean = 0.000,    deviation = 1.000
#
#
# MinMax Scaling:
#
# 12 Chromagram features:           min = 0.000,     max = 1.000,     mean = 0.611,     deviation = 0.181
#
# 128 Mel Spectrogram features:     min = 0.000,     max = 1.000,     mean = 0.015,     deviation = 0.061
#
# 40 MFCC features:                 min = 0.000,    max = 1.000,    mean = 0.406,    deviation = 0.166

# %% [markdown]
# import os, glob
# import numpy as np
# import librosaPerfect. Zero mean and unit variance for standard scaling and in the range [0,1] for MinMax scaling - a default when we don't specify values. We can now move on to building predictive models for these features.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import librosa.display
import soundfile
import os
